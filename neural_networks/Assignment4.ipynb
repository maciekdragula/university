# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %% [markdown]
# # Assignment 4
#
# **Submission deadline:**
#
# **problems 1-2 last lab session before or on Wednesday, 30.11.18**
#
# **problems 3-8 last lab session before or on Wednesday, 7.12.18**
#
#
# **Points: 11 + 5 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Colab/Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!
#
# If you use Colab please make sure to have a GPU runtime (```Runtime -> Change runtime type -> Hardware Accelarater = GPU```)

# %%
# Please note that this code needs only to be run in a fresh runtime.
# However, it can be rerun afterwards too.
# !pip install -q gdown httpimport
![ -e cifar.npz ] || gdown 'https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR' -O cifar.npz
![ -e mnist.npz ] || gdown 'https://drive.google.com/uc?id=1QPaC3IKB_5tX6yIZgRgkpcqFrfVqPTXU' -O mnist.npz

# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oBzZdtg2zNTPGhbRy6DQ_wrf5L5OAhNR
# To: /content/cifar.npz
# 185MB [00:01, 151MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QPaC3IKB_5tX6yIZgRgkpcqFrfVqPTXU
# To: /content/mnist.npz
# 55.4MB [00:00, 152MB/s]
# tcmalloc: large alloc 1073750016 bytes == 0x5651c1c52000 @  0x7f90ded4c2a4 0x565168e4ff18 0x565168f43a85 0x565168e634ca 0x565168e68232 0x565168e60d0a 0x565168e685fe 0x565168e60d0a 0x565168e685fe 0x565168e60d0a 0x565168e685fe 0x565168e60d0a 0x565168e68c38 0x565168e60d0a 0x565168e685fe 0x565168e60d0a 0x565168e685fe 0x565168e68232 0x565168e68232 0x565168e60d0a 0x565168e68c38 0x565168e68232 0x565168e60d0a 0x565168e68c38 0x565168e60d0a 0x565168e68c38 0x565168e60d0a 0x565168e685fe 0x565168e60d0a 0x565168e60629 0x565168e9161f

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Getting to know PyTorch
#
# From now on, we will use [pytorch](https://pytorch.org/) to implement neural networks.
#
# Good introductions are the [60-minute tutorial](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) and [pytorch examples](https://pytorch.org/tutorials/beginner/pytorch_with_examples.html).
#
#
# Pytorch has a set of modules to build neural networks. However, for simplicity, this assignment will use a custom, simple neural network code.

# %%
import numpy as np
import time
import torch
import torch.nn.functional as F


class Layer(object):
    def __init__(self):
        self.mode = True
    
    def train_mode(self):
        """Put layer into training mode.
        
        This is useful for e.g. Dropout.
        """
        self.training = True
    
    def eval_mode(self):
        """Put layer into evalation mode.
        
        This is useful for e.g. Dropout.
        """
        self.training = False
    
    def to_device(self, device):
        """Move this layer's parameters to thie given device (cpu/cuda).
        """
        pass
    
    @property
    def parameters(self):
        return []
    
    def __repr__(self):
        param_s = ', '.join(['%s%s' % (n, tuple(p.size())) 
                                 for (n,p) in self.parameters])
        if not param_s:
            return '  %s with no params' % (self.__class__.__name__)
        else:
            return '  %s with params: %s' % (self.__class__.__name__, param_s)
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = torch.empty(num_in, num_out, dtype=torch.float32, requires_grad=True)
        self.b = torch.empty(1, num_out, dtype=torch.float32, requires_grad=True)
    
    @property
    def parameters(self):
        return [('W', self.W), ('b', self.b)]
    
    def forward(self, x):
        return x.mm(self.W) + self.b
    
    def to_device(self, device):
        with torch.no_grad():
            self.W = self.W.to(device).requires_grad_()
            self.b = self.b.to(device).requires_grad_()

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x, dim=-1)

class CrossEntropyLoss:
    def forward(self, probs, targets):
        return torch.mean(-torch.log(torch.gather(
            probs, 1, targets.unsqueeze(1))))

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers
        self.loss_fn = CrossEntropyLoss()

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for (_, ownP), newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def to_device(self, device):
        for layer in self.layers:
            layer.to_device(device)
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return self.loss_fn.forward(outputs, targets)
    
    def __repr__(self):
        strs = ["Feedorward network with %d layers:" % (len(self.layers),)]
        for layer in self.layers:
            strs.append(repr(layer))
        return '\n'.join(strs)

# %%
from sklearn import datasets

iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

IrisX = torch.from_numpy(IrisX)
IrisY = torch.from_numpy(IrisY)

# %%
def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6, device='cpu'):
    """Simple batch gradient descent"""
    x = x.to(device)
    y = y.to(device)
    model.to_device(device)
    try:
        old_loss = np.inf
        model.train_mode()
        tstart = time.time()
        for i in xrange(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            
            # this disables autograd mechanism and allows us to 
            with torch.torch.no_grad():
                for _, p in model.parameters:
                    p -= p.grad * alpha
                    # Zero gradients for the next iteration
                    p.grad.zero_()

            loss = loss.item()
            if old_loss < loss:
                print("Iter: %d, loss increased!" % (i,))
            if (old_loss - loss) < tolerance:
                print("Tolerance level reached. Exiting.")
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print("Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}% | steps/s {3: >5.2f}" \
                      .format(i, loss, err_rate, (1000 if i else 1) / (time.time() - tstart)))
                tstart = time.time()
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     AffineLayer(10, 3),
     SoftMaxLayer(),
    ])


# Initialize parameters
with torch.torch.no_grad():
    for n, p in model.parameters:
        if n == 'W':
            # p.data.normal_(0, 0.05)
            p.uniform_(-0.1, 0.1)
        elif n == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
# Iris is so small, that trainingon CPU is faster!
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7, device='cpu')
# Out:
# Iteration      0 | loss  1.09 | err rate  48.00% | steps/s 431.60
# Iteration   1000 | loss  0.05 | err rate   2.00% | steps/s 1676.90
# Iteration   2000 | loss  0.04 | err rate   2.00% | steps/s 1735.23
# Iteration   3000 | loss  0.04 | err rate   1.00% | steps/s 1697.45
# Iteration   4000 | loss  0.04 | err rate   1.00% | steps/s 1674.90
# Iteration   5000 | loss  0.04 | err rate   1.00% | steps/s 1711.54
# Iteration   6000 | loss  0.04 | err rate   1.00% | steps/s 1676.16
# Iteration   7000 | loss  0.04 | err rate   1.00% | steps/s 1750.23
# Iteration   8000 | loss  0.04 | err rate   1.00% | steps/s 1683.65
# Iteration   9000 | loss  0.04 | err rate   1.00% | steps/s 1748.64
# Iteration  10000 | loss  0.04 | err rate   1.00% | steps/s 1718.49
# Iteration  11000 | loss  0.04 | err rate   1.00% | steps/s 1734.86
# Iteration  12000 | loss  0.04 | err rate   1.00% | steps/s 1717.66
# Iteration  13000 | loss  0.04 | err rate   1.00% | steps/s 1672.89
# Iteration  14000 | loss  0.04 | err rate   1.00% | steps/s 1747.81
# Iteration  15000 | loss  0.04 | err rate   1.00% | steps/s 1702.73
# Iteration  16000 | loss  0.04 | err rate   1.00% | steps/s 1739.73
# Iteration  17000 | loss  0.04 | err rate   1.00% | steps/s 1713.78
# Iteration  18000 | loss  0.04 | err rate   1.00% | steps/s 1739.28
# Iteration  19000 | loss  0.04 | err rate   1.00% | steps/s 1712.89
# Iteration  20000 | loss  0.04 | err rate   1.00% | steps/s 1699.51
# Iteration  21000 | loss  0.03 | err rate   1.00% | steps/s 1744.40
# Iteration  22000 | loss  0.03 | err rate   1.00% | steps/s 1691.75
# Iteration  23000 | loss  0.03 | err rate   1.00% | steps/s 1749.91
# Iteration  24000 | loss  0.03 | err rate   1.00% | steps/s 1713.51
# Iteration  25000 | loss  0.03 | err rate   1.00% | steps/s 1739.05
# Iteration  26000 | loss  0.03 | err rate   1.00% | steps/s 1704.68
# Iteration  27000 | loss  0.03 | err rate   1.00% | steps/s 1710.17
# Iteration  28000 | loss  0.03 | err rate   1.00% | steps/s 1698.14
# Iteration  29000 | loss  0.03 | err rate   1.00% | steps/s 1718.34
# Iteration  30000 | loss  0.03 | err rate   1.00% | steps/s 1749.13
# Iteration  31000 | loss  0.03 | err rate   1.00% | steps/s 1712.13
# Iteration  32000 | loss  0.03 | err rate   1.00% | steps/s 1728.35
# Iteration  33000 | loss  0.03 | err rate   1.00% | steps/s 1722.23
# Iteration  34000 | loss  0.03 | err rate   1.00% | steps/s 1744.91
# Iteration  35000 | loss  0.03 | err rate   1.00% | steps/s 1691.51
# Iteration  36000 | loss  0.02 | err rate   1.00% | steps/s 1677.96
# Iteration  37000 | loss  0.02 | err rate   1.00% | steps/s 1742.25
# Iteration  38000 | loss  0.02 | err rate   1.00% | steps/s 1706.32
# Iteration  39000 | loss  0.02 | err rate   1.00% | steps/s 1720.11
# Iteration  40000 | loss  0.02 | err rate   1.00% | steps/s 1682.43
# Iteration  41000 | loss  0.02 | err rate   1.00% | steps/s 1721.84
# Iteration  42000 | loss  0.02 | err rate   1.00% | steps/s 1689.42
# Iteration  43000 | loss  0.02 | err rate   1.00% | steps/s 1678.54
# Iteration  44000 | loss  0.02 | err rate   0.00% | steps/s 1710.68
# Iteration  45000 | loss  0.02 | err rate   0.00% | steps/s 1687.22
# Iteration  46000 | loss  0.02 | err rate   0.00% | steps/s 1666.11
# Iteration  47000 | loss  0.01 | err rate   0.00% | steps/s 1706.40
# Iteration  48000 | loss  0.01 | err rate   0.00% | steps/s 1722.53
# Iteration  49000 | loss  0.01 | err rate   0.00% | steps/s 1687.09
# Iteration  50000 | loss  0.01 | err rate   0.00% | steps/s 1670.96
# Iteration  51000 | loss  0.01 | err rate   0.00% | steps/s 1717.81
# Iteration  52000 | loss  0.01 | err rate   0.00% | steps/s 1691.41
# Iteration  53000 | loss  0.01 | err rate   0.00% | steps/s 1721.92
# Iteration  54000 | loss  0.01 | err rate   0.00% | steps/s 1676.46
# Iteration  55000 | loss  0.01 | err rate   0.00% | steps/s 1731.36
# Iteration  56000 | loss  0.01 | err rate   0.00% | steps/s 1702.01
# Iteration  57000 | loss  0.01 | err rate   0.00% | steps/s 1705.84
# Iteration  58000 | loss  0.01 | err rate   0.00% | steps/s 1750.57
# Iteration  59000 | loss  0.01 | err rate   0.00% | steps/s 1704.36
# Iteration  60000 | loss  0.01 | err rate   0.00% | steps/s 1743.84
# Iteration  61000 | loss  0.01 | err rate   0.00% | steps/s 1693.26
# Iteration  62000 | loss  0.01 | err rate   0.00% | steps/s 1711.76
# Iteration  63000 | loss  0.01 | err rate   0.00% | steps/s 1693.74
# Iteration  64000 | loss  0.00 | err rate   0.00% | steps/s 1718.79
# Iteration  65000 | loss  0.00 | err rate   0.00% | steps/s 1679.23
# Iteration  66000 | loss  0.00 | err rate   0.00% | steps/s 1695.16
# Iteration  67000 | loss  0.00 | err rate   0.00% | steps/s 1735.77
# Iteration  68000 | loss  0.00 | err rate   0.00% | steps/s 1675.11
# Iteration  69000 | loss  0.00 | err rate   0.00% | steps/s 1741.26
# Iteration  70000 | loss  0.00 | err rate   0.00% | steps/s 1709.26
# Iteration  71000 | loss  0.00 | err rate   0.00% | steps/s 1719.87
# Iteration  72000 | loss  0.00 | err rate   0.00% | steps/s 1693.41
# Iteration  73000 | loss  0.00 | err rate   0.00% | steps/s 1688.93
# Iteration  74000 | loss  0.00 | err rate   0.00% | steps/s 1706.79
# Iteration  75000 | loss  0.00 | err rate   0.00% | steps/s 1700.91
# Iteration  76000 | loss  0.00 | err rate   0.00% | steps/s 1730.73
# Tolerance level reached. Exiting.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import os
import torch
import torchvision


batch_size = 128
data_path = './data'

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True,
        pin_memory=True, num_workers=10),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}

# %% [markdown]
# # Problem 1: Stochastic Gradient Descent [3p]
# Implement the following additions to the SGD code provided below (in task 2):
#   1. **[1p]** momentum
#   2. **[1p]** learning rate schedule
#   3. **[1p]** weight decay, in which we additionally minimize for each weight matrix (but typically not the bias) the sum of its elements squared. One way to implement it is to use function `model.parameters` and select all parameters whose names are "`W`" and not "`b`".

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
def compute_error_rate(model, data_loader, device='cpu'):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    # we don't need gradient during eval!
    with torch.no_grad():
        for x, y in data_loader:
            x = x.to(device).view(x.size(0), -1)
            y = y.to(device)
            outputs = model.forward(x)
            _, predictions = outputs.data.max(dim=1)
            num_errs += (predictions != y.data).sum().item()
            num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, device='cpu', epsilon=0.3):
    model.to_device(device)
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    #
    velocities = [torch.zeros(p[1].size(), dtype=torch.float, device='cuda') for p in model.parameters]
    prev_velocities = [torch.zeros(p[1].size(), dtype=torch.float, device='cuda') for p in model.parameters]
    #
    iter_ = 0
    epoch = 0
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        tstart = time.time()
        siter = iter_
        while epoch < num_epochs:
            model.train_mode()
            epoch += 1
            for x, y in data_loaders['train']:
                x = x.to(device).view(x.size(0), -1)
                y = y.to(device)
                iter_ += 1
                out = model.forward(x)
                loss = model.loss(out, y)
                loss.backward()
                _, predictions = out.max(dim=1)
                err_rate = 100.0 * (predictions != y).sum().item() / out.size(0)

                history['train_losses'].append(loss.item())
                history['train_errs'].append(err_rate)
                
                # disable gradient computations - we do not want torch to
                # backpropagate through the gradient application!
                with torch.no_grad():
                    for (name, p), v, prev_v in zip(model.parameters, 
                                                    velocities, 
                                                    prev_velocities):
                        if name == 'W':
                        #
                        # TODO: Implement weight decay addition to gradients
                            p.grad += 0.00035 * p
                        # 

                        
                        #
                        # TODO: Implement velocity update in momentum
                        # lease make sure to modify the contents of v, not the v pointer!!!
                            v_prev = v
                            v = epsilon * v - alpha * p.grad
                        #

                        #
                        # TODO: Set a more sensible learning rule here,
                        #       using your learning rate schedule and momentum
                        # 
                            p += -epsilon * v_prev + (1 + epsilon) * v
                        # Zero gradients for the next iteration
                        p.grad.zero_()       
                #
                # TODO: Update learning rate
                # Hint: Use the iteration counter i
                #
                #
                # Anneal alpha and epsilon
                alpha *= 0.999971
                epsilon *= 1.000016 # < 1
                if iter_ % log_every == 0:
                    num_iter = iter_ - siter + 1
                    print "Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%, steps/s {3: >5.2f}" \
                          .format(iter_, loss.item(), err_rate, num_iter / (time.time() - tstart))
                    tstart = time.time()
                           
            
            val_err_rate = compute_error_rate(model, data_loaders['valid'], device)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.detach().cpu() for (_, p) in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
     AffineLayer(784, 2100),
     ReLULayer(),
     AffineLayer(2100, 850),
     ReLULayer(),
     AffineLayer(850, 10),
     SoftMaxLayer()
    ])


with torch.no_grad():
    # Initialize parameters
    for name, p in model.parameters:
        if name == 'W':
            # TODO: initalization
            torch.nn.init.xavier_normal_(p)
        elif name == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

# On GPU enabled devices set device='cuda' else set device='cpu'
SGD(model, mnist_loaders, alpha=0.06, device='cuda')

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.40 | err rate  9.38%, steps/s 54.98
# Minibatch    200  | loss  0.15 | err rate  4.69%, steps/s 105.00
# Minibatch    300  | loss  0.23 | err rate  7.81%, steps/s 164.12
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  4.07% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.09 | err rate  3.12%, steps/s 105.22
# Minibatch    500  | loss  0.16 | err rate  3.12%, steps/s 269.31
# Minibatch    600  | loss  0.09 | err rate  2.34%, steps/s 311.82
# Minibatch    700  | loss  0.03 | err rate  0.78%, steps/s 372.88
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.99% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.08 | err rate  1.56%, steps/s 207.40
# Minibatch    900  | loss  0.12 | err rate  4.69%, steps/s 483.52
# Minibatch   1000  | loss  0.08 | err rate  2.34%, steps/s 526.11
# Minibatch   1100  | loss  0.12 | err rate  2.34%, steps/s 577.72
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.69% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.07 | err rate  1.56%, steps/s 316.84
# Minibatch   1300  | loss  0.06 | err rate  0.78%, steps/s 684.49
# Minibatch   1400  | loss  0.05 | err rate  2.34%, steps/s 737.28
# Minibatch   1500  | loss  0.07 | err rate  2.34%, steps/s 801.07
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.26% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.06 | err rate  2.34%, steps/s 418.95
# Minibatch   1700  | loss  0.08 | err rate  2.34%, steps/s 903.12
# Minibatch   1800  | loss  0.02 | err rate  0.00%, steps/s 959.07
# Minibatch   1900  | loss  0.03 | err rate  0.00%, steps/s 1006.90
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  2.21% | doing   8 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.03 | err rate  0.00%, steps/s 530.88
# Minibatch   2100  | loss  0.02 | err rate  0.00%, steps/s 1117.75
# Minibatch   2200  | loss  0.02 | err rate  0.00%, steps/s 1174.69
# Minibatch   2300  | loss  0.02 | err rate  0.00%, steps/s 1204.71
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  2.14% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.01 | err rate  0.00%, steps/s 637.22
# Minibatch   2500  | loss  0.02 | err rate  0.00%, steps/s 1315.61
# Minibatch   2600  | loss  0.02 | err rate  0.00%, steps/s 1384.99
# Minibatch   2700  | loss  0.02 | err rate  0.00%, steps/s 1415.76
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.93% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.02 | err rate  0.00%, steps/s 734.20
# Minibatch   2900  | loss  0.02 | err rate  0.00%, steps/s 1510.22
# Minibatch   3000  | loss  0.03 | err rate  0.78%, steps/s 1591.18
# Minibatch   3100  | loss  0.02 | err rate  0.00%, steps/s 1679.48
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  2.04% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.02 | err rate  0.00%, steps/s 830.43
# Minibatch   3300  | loss  0.01 | err rate  0.00%, steps/s 1748.24
# Minibatch   3400  | loss  0.02 | err rate  0.00%, steps/s 1825.20
# Minibatch   3500  | loss  0.02 | err rate  0.78%, steps/s 1833.16
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.90% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.01 | err rate  0.00%, steps/s 953.09
# Minibatch   3700  | loss  0.01 | err rate  0.00%, steps/s 1988.25
# Minibatch   3800  | loss  0.01 | err rate  0.00%, steps/s 2017.89
# Minibatch   3900  | loss  0.01 | err rate  0.00%, steps/s 2224.51
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.88% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.01 | err rate  0.00%, steps/s 1033.03
# Minibatch   4100  | loss  0.01 | err rate  0.00%, steps/s 2182.49
# Minibatch   4200  | loss  0.01 | err rate  0.00%, steps/s 2236.05
# Minibatch   4300  | loss  0.00 | err rate  0.00%, steps/s 2611.87
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.94% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.01 | err rate  0.00%, steps/s 1100.22
# Minibatch   4500  | loss  0.01 | err rate  0.00%, steps/s 2377.06
# Minibatch   4600  | loss  0.01 | err rate  0.00%, steps/s 2430.11
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.82% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.02 | err rate  0.78%, steps/s 1235.52
# Minibatch   4800  | loss  0.01 | err rate  0.00%, steps/s 2533.30
# Minibatch   4900  | loss  0.01 | err rate  0.00%, steps/s 2571.39
# Minibatch   5000  | loss  0.01 | err rate  0.00%, steps/s 2672.96
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.93% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.00 | err rate  0.00%, steps/s 1336.69
# Minibatch   5200  | loss  0.01 | err rate  0.00%, steps/s 2730.94
# Minibatch   5300  | loss  0.01 | err rate  0.00%, steps/s 2828.43
# Minibatch   5400  | loss  0.01 | err rate  0.00%, steps/s 2859.86
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.75% | doing  22 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.01 | err rate  0.00%, steps/s 1460.92
# Minibatch   5600  | loss  0.01 | err rate  0.00%, steps/s 2968.17
# Minibatch   5700  | loss  0.01 | err rate  0.00%, steps/s 3071.39
# Minibatch   5800  | loss  0.01 | err rate  0.00%, steps/s 3133.75
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.75% | doing  22 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.01 | err rate  0.00%, steps/s 1574.17
# Minibatch   6000  | loss  0.00 | err rate  0.00%, steps/s 3237.34
# Minibatch   6100  | loss  0.01 | err rate  0.00%, steps/s 3284.19
# Minibatch   6200  | loss  0.00 | err rate  0.00%, steps/s 3327.70
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.79% | doing  22 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.01 | err rate  0.00%, steps/s 1651.25
# Minibatch   6400  | loss  0.00 | err rate  0.00%, steps/s 3402.60
# Minibatch   6500  | loss  0.00 | err rate  0.00%, steps/s 3397.65
# Minibatch   6600  | loss  0.01 | err rate  0.00%, steps/s 3525.78
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.76% | doing  22 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.00 | err rate  0.00%, steps/s 1766.33
# Minibatch   6800  | loss  0.01 | err rate  0.00%, steps/s 3564.52
# Minibatch   6900  | loss  0.01 | err rate  0.00%, steps/s 3697.46
# Minibatch   7000  | loss  0.01 | err rate  0.00%, steps/s 3707.81
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.73% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.00 | err rate  0.00%, steps/s 1882.25
# Minibatch   7200  | loss  0.01 | err rate  0.00%, steps/s 3833.36
# Minibatch   7300  | loss  0.01 | err rate  0.00%, steps/s 3858.85
# Minibatch   7400  | loss  0.00 | err rate  0.00%, steps/s 3929.75
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.83% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.00 | err rate  0.00%, steps/s 1999.74
# Minibatch   7600  | loss  0.00 | err rate  0.00%, steps/s 4017.30
# Minibatch   7700  | loss  0.00 | err rate  0.00%, steps/s 4070.70
# Minibatch   7800  | loss  0.01 | err rate  0.00%, steps/s 4119.04
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.78% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.00 | err rate  0.00%, steps/s 2119.72
# Minibatch   8000  | loss  0.01 | err rate  0.00%, steps/s 4257.06
# Minibatch   8100  | loss  0.01 | err rate  0.00%, steps/s 4305.91
# Minibatch   8200  | loss  0.01 | err rate  0.00%, steps/s 4605.14
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  1.79% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.00 | err rate  0.00%, steps/s 2148.35
# Minibatch   8400  | loss  0.01 | err rate  0.00%, steps/s 4411.62
# Minibatch   8500  | loss  0.00 | err rate  0.00%, steps/s 4490.94
# Minibatch   8600  | loss  0.01 | err rate  0.00%, steps/s 5129.45
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.78% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.00 | err rate  0.00%, steps/s 2186.39
# Minibatch   8800  | loss  0.00 | err rate  0.00%, steps/s 4692.28
# Minibatch   8900  | loss  0.00 | err rate  0.00%, steps/s 4721.33
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.80% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.01 | err rate  0.00%, steps/s 2409.82
# Minibatch   9100  | loss  0.00 | err rate  0.00%, steps/s 4640.34
# Minibatch   9200  | loss  0.01 | err rate  0.00%, steps/s 4893.65
# Minibatch   9300  | loss  0.00 | err rate  0.00%, steps/s 4920.20
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.74% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.01 | err rate  0.00%, steps/s 2479.27
# Minibatch   9500  | loss  0.00 | err rate  0.00%, steps/s 5055.26
# Minibatch   9600  | loss  0.00 | err rate  0.00%, steps/s 5127.06
# Minibatch   9700  | loss  0.00 | err rate  0.00%, steps/s 5188.05
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  1.70% | doing  38 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.01 | err rate  0.00%, steps/s 2578.02
# Minibatch   9900  | loss  0.00 | err rate  0.00%, steps/s 5233.51
# Minibatch  10000  | loss  0.01 | err rate  0.00%, steps/s 5314.64
# Minibatch  10100  | loss  0.00 | err rate  0.00%, steps/s 5446.18
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  1.77% | doing  38 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.01 | err rate  0.00%, steps/s 2709.31
# Minibatch  10300  | loss  0.01 | err rate  0.00%, steps/s 5339.95
# Minibatch  10400  | loss  0.01 | err rate  0.00%, steps/s 5509.82
# Minibatch  10500  | loss  0.00 | err rate  0.00%, steps/s 5635.32
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.69% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.01 | err rate  0.00%, steps/s 2762.59
# Minibatch  10700  | loss  0.00 | err rate  0.00%, steps/s 5637.04
# Minibatch  10800  | loss  0.01 | err rate  0.00%, steps/s 5718.75
# Minibatch  10900  | loss  0.00 | err rate  0.00%, steps/s 5798.69
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.77% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.00 | err rate  0.00%, steps/s 2918.20
# Minibatch  11100  | loss  0.00 | err rate  0.00%, steps/s 5954.91
# Minibatch  11200  | loss  0.00 | err rate  0.00%, steps/s 5924.92
# Minibatch  11300  | loss  0.01 | err rate  0.00%, steps/s 6022.78
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.76% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  11400  | loss  0.00 | err rate  0.00%, steps/s 3048.03
# Minibatch  11500  | loss  0.01 | err rate  0.00%, steps/s 6255.95
# Minibatch  11600  | loss  0.00 | err rate  0.00%, steps/s 5971.88
# Minibatch  11700  | loss  0.00 | err rate  0.00%, steps/s 6201.49
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.80% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.00 | err rate  0.00%, steps/s 3171.15
# Minibatch  11900  | loss  0.00 | err rate  0.00%, steps/s 6231.59
# Minibatch  12000  | loss  0.01 | err rate  0.00%, steps/s 6403.04
# Minibatch  12100  | loss  0.00 | err rate  0.00%, steps/s 6438.00
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.75% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  12200  | loss  0.00 | err rate  0.00%, steps/s 3271.61
# Minibatch  12300  | loss  0.00 | err rate  0.00%, steps/s 6597.35
# Minibatch  12400  | loss  0.01 | err rate  0.00%, steps/s 6509.41
# Minibatch  12500  | loss  0.00 | err rate  0.00%, steps/s 6823.99
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  1.80% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.00 | err rate  0.00%, steps/s 3229.67
# Minibatch  12700  | loss  0.00 | err rate  0.00%, steps/s 6731.81
# Minibatch  12800  | loss  0.01 | err rate  0.00%, steps/s 6796.76
# Minibatch  12900  | loss  0.00 | err rate  0.00%, steps/s 7492.57
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  1.74% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  13000  | loss  0.00 | err rate  0.00%, steps/s 3296.18
# Minibatch  13100  | loss  0.00 | err rate  0.00%, steps/s 7061.44
# Minibatch  13200  | loss  0.00 | err rate  0.00%, steps/s 6875.81
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  1.72% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.00 | err rate  0.00%, steps/s 3566.59
# Minibatch  13400  | loss  0.00 | err rate  0.00%, steps/s 6962.89
# Minibatch  13500  | loss  0.00 | err rate  0.00%, steps/s 7018.56
# Minibatch  13600  | loss  0.00 | err rate  0.00%, steps/s 7282.06
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  1.75% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  13700  | loss  0.00 | err rate  0.00%, steps/s 3626.25
# Minibatch  13800  | loss  0.00 | err rate  0.00%, steps/s 7364.50
# Minibatch  13900  | loss  0.00 | err rate  0.00%, steps/s 7447.69
# Minibatch  14000  | loss  0.00 | err rate  0.00%, steps/s 7394.21
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  1.75% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.00 | err rate  0.00%, steps/s 3712.47
# Minibatch  14200  | loss  0.00 | err rate  0.00%, steps/s 7517.53
# Minibatch  14300  | loss  0.00 | err rate  0.00%, steps/s 7527.77
# Minibatch  14400  | loss  0.00 | err rate  0.00%, steps/s 7596.97
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  1.75% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  14500  | loss  0.00 | err rate  0.00%, steps/s 3833.28
# Minibatch  14600  | loss  0.00 | err rate  0.00%, steps/s 7762.55
# Minibatch  14700  | loss  0.00 | err rate  0.00%, steps/s 7728.10
# Minibatch  14800  | loss  0.01 | err rate  0.00%, steps/s 7899.24
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  1.70% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.00 | err rate  0.00%, steps/s 3945.58
# Minibatch  15000  | loss  0.00 | err rate  0.00%, steps/s 7935.76
# Minibatch  15100  | loss  0.00 | err rate  0.00%, steps/s 7961.92
# Minibatch  15200  | loss  0.00 | err rate  0.00%, steps/s 8120.86
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  1.68% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  15300  | loss  0.00 | err rate  0.00%, steps/s 4072.61
# Minibatch  15400  | loss  0.00 | err rate  0.00%, steps/s 8120.39
# Minibatch  15500  | loss  0.00 | err rate  0.00%, steps/s 8319.80
# Minibatch  15600  | loss  0.00 | err rate  0.00%, steps/s 8241.28
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  1.77% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.00 | err rate  0.00%, steps/s 4166.26
# Minibatch  15800  | loss  0.00 | err rate  0.00%, steps/s 8482.94
# Minibatch  15900  | loss  0.01 | err rate  0.00%, steps/s 8543.11
# Minibatch  16000  | loss  0.00 | err rate  0.00%, steps/s 8582.01
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  1.77% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  16100  | loss  0.00 | err rate  0.00%, steps/s 4258.60
# Minibatch  16200  | loss  0.00 | err rate  0.00%, steps/s 8580.08
# Minibatch  16300  | loss  0.00 | err rate  0.00%, steps/s 8644.80
# Minibatch  16400  | loss  0.00 | err rate  0.00%, steps/s 8561.70
# ----------------------------------------------------------
# After epoch 42 | valid err rate:  1.78% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  16500  | loss  0.00 | err rate  0.00%, steps/s 4397.65
# Minibatch  16600  | loss  0.00 | err rate  0.00%, steps/s 9041.37
# Minibatch  16700  | loss  0.00 | err rate  0.00%, steps/s 9008.42
# Minibatch  16800  | loss  0.00 | err rate  0.00%, steps/s 9368.22
# ----------------------------------------------------------
# After epoch 43 | valid err rate:  1.73% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  16900  | loss  0.00 | err rate  0.00%, steps/s 4436.41
# Minibatch  17000  | loss  0.00 | err rate  0.00%, steps/s 9156.89
# Minibatch  17100  | loss  0.01 | err rate  0.00%, steps/s 9256.47
# Minibatch  17200  | loss  0.00 | err rate  0.00%, steps/s 10092.33
# ----------------------------------------------------------
# After epoch 44 | valid err rate:  1.73% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  17300  | loss  0.01 | err rate  0.00%, steps/s 4377.66
# Minibatch  17400  | loss  0.01 | err rate  0.00%, steps/s 9295.31
# Minibatch  17500  | loss  0.00 | err rate  0.00%, steps/s 9273.02
# ----------------------------------------------------------
# After epoch 45 | valid err rate:  1.69% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  17600  | loss  0.00 | err rate  0.00%, steps/s 4773.14
# Minibatch  17700  | loss  0.00 | err rate  0.00%, steps/s 8991.93
# Minibatch  17800  | loss  0.00 | err rate  0.00%, steps/s 9523.03
# Minibatch  17900  | loss  0.00 | err rate  0.00%, steps/s 9484.57
# ----------------------------------------------------------
# After epoch 46 | valid err rate:  1.69% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  18000  | loss  0.00 | err rate  0.00%, steps/s 4762.29
# Minibatch  18100  | loss  0.00 | err rate  0.00%, steps/s 9460.28
# Minibatch  18200  | loss  0.00 | err rate  0.00%, steps/s 9698.57
# Minibatch  18300  | loss  0.00 | err rate  0.00%, steps/s 9714.83
# ----------------------------------------------------------
# After epoch 47 | valid err rate:  1.77% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  18400  | loss  0.00 | err rate  0.00%, steps/s 4932.92
# Minibatch  18500  | loss  0.00 | err rate  0.00%, steps/s 9846.09
# Minibatch  18600  | loss  0.00 | err rate  0.00%, steps/s 9967.72
# Minibatch  18700  | loss  0.01 | err rate  0.00%, steps/s 10113.90
# ----------------------------------------------------------
# After epoch 48 | valid err rate:  1.74% | doing  59 epochs
# ----------------------------------------------------------
# Minibatch  18800  | loss  0.00 | err rate  0.00%, steps/s 5045.60
# Minibatch  18900  | loss  0.01 | err rate  0.00%, steps/s 10353.33
# Minibatch  19000  | loss  0.00 | err rate  0.00%, steps/s 10222.95
# Minibatch  19100  | loss  0.00 | err rate  0.00%, steps/s 10288.10
# ----------------------------------------------------------
# After epoch 49 | valid err rate:  1.66% | doing  74 epochs
# ----------------------------------------------------------
# Minibatch  19200  | loss  0.00 | err rate  0.00%, steps/s 5126.59
# Minibatch  19300  | loss  0.00 | err rate  0.00%, steps/s 10393.33
# Minibatch  19400  | loss  0.00 | err rate  0.00%, steps/s 10324.51
# Minibatch  19500  | loss  0.00 | err rate  0.00%, steps/s 10324.19
# ----------------------------------------------------------
# After epoch 50 | valid err rate:  1.71% | doing  74 epochs
# ----------------------------------------------------------
# Minibatch  19600  | loss  0.00 | err rate  0.00%, steps/s 5340.88
# Minibatch  19700  | loss  0.00 | err rate  0.00%, steps/s 10487.55
# Minibatch  19800  | loss  0.00 | err rate  0.00%, steps/s 10602.16
# Minibatch  19900  | loss  0.01 | err rate  0.00%, steps/s 10971.93
# ----------------------------------------------------------
# After epoch 51 | valid err rate:  1.71% | doing  74 epochs
# ----------------------------------------------------------
# Minibatch  20000  | loss  0.00 | err rate  0.00%, steps/s 5321.79
# Minibatch  20100  | loss  0.00 | err rate  0.00%, steps/s 10911.88
# Minibatch  20200  | loss  0.00 | err rate  0.00%, steps/s 10619.31
# Minibatch  20300  | loss  0.00 | err rate  0.00%, steps/s 10952.78
# ----------------------------------------------------------
# After epoch 52 | valid err rate:  1.67% | doing  74 epochs
# ----------------------------------------------------------
# Minibatch  20400  | loss  0.00 | err rate  0.00%, steps/s 5481.71
# Minibatch  20500  | loss  0.01 | err rate  0.00%, steps/s 10785.73
# Minibatch  20600  | loss  0.00 | err rate  0.00%, steps/s 11080.11
# Minibatch  20700  | loss  0.00 | err rate  0.00%, steps/s 10917.54
# ----------------------------------------------------------
# After epoch 53 | valid err rate:  1.66% | doing  74 epochs
# ----------------------------------------------------------
# Minibatch  20800  | loss  0.00 | err rate  0.00%, steps/s 5520.34
# Minibatch  20900  | loss  0.00 | err rate  0.00%, steps/s 11115.68
# Minibatch  21000  | loss  0.01 | err rate  0.00%, steps/s 11285.57
# Minibatch  21100  | loss  0.00 | err rate  0.00%, steps/s 11461.48
# ----------------------------------------------------------
# After epoch 54 | valid err rate:  1.62% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  21200  | loss  0.01 | err rate  0.00%, steps/s 5476.84
# Minibatch  21300  | loss  0.00 | err rate  0.00%, steps/s 11530.14
# Minibatch  21400  | loss  0.00 | err rate  0.00%, steps/s 11115.55
# Minibatch  21500  | loss  0.00 | err rate  0.00%, steps/s 12336.10
# ----------------------------------------------------------
# After epoch 55 | valid err rate:  1.70% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  21600  | loss  0.00 | err rate  0.00%, steps/s 5455.03
# Minibatch  21700  | loss  0.00 | err rate  0.00%, steps/s 11537.31
# Minibatch  21800  | loss  0.00 | err rate  0.00%, steps/s 11581.88
# ----------------------------------------------------------
# After epoch 56 | valid err rate:  1.70% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  21900  | loss  0.00 | err rate  0.00%, steps/s 5969.04
# Minibatch  22000  | loss  0.00 | err rate  0.00%, steps/s 11185.21
# Minibatch  22100  | loss  0.00 | err rate  0.00%, steps/s 11711.86
# Minibatch  22200  | loss  0.00 | err rate  0.00%, steps/s 11744.46
# ----------------------------------------------------------
# After epoch 57 | valid err rate:  1.67% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  22300  | loss  0.00 | err rate  0.00%, steps/s 5902.48
# Minibatch  22400  | loss  0.00 | err rate  0.00%, steps/s 11978.82
# Minibatch  22500  | loss  0.00 | err rate  0.00%, steps/s 12201.35
# Minibatch  22600  | loss  0.00 | err rate  0.00%, steps/s 12255.01
# ----------------------------------------------------------
# After epoch 58 | valid err rate:  1.68% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  22700  | loss  0.00 | err rate  0.00%, steps/s 5980.86
# Minibatch  22800  | loss  0.00 | err rate  0.00%, steps/s 12087.29
# Minibatch  22900  | loss  0.00 | err rate  0.00%, steps/s 12312.84
# Minibatch  23000  | loss  0.00 | err rate  0.00%, steps/s 12376.14
# ----------------------------------------------------------
# After epoch 59 | valid err rate:  1.70% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  23100  | loss  0.00 | err rate  0.00%, steps/s 6082.19
# Minibatch  23200  | loss  0.00 | err rate  0.00%, steps/s 12582.78
# Minibatch  23300  | loss  0.00 | err rate  0.00%, steps/s 12703.06
# Minibatch  23400  | loss  0.00 | err rate  0.00%, steps/s 12473.48
# ----------------------------------------------------------
# After epoch 60 | valid err rate:  1.72% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  23500  | loss  0.00 | err rate  0.00%, steps/s 6337.90
# Minibatch  23600  | loss  0.00 | err rate  0.00%, steps/s 12683.78
# Minibatch  23700  | loss  0.00 | err rate  0.00%, steps/s 12952.65
# Minibatch  23800  | loss  0.00 | err rate  0.00%, steps/s 12995.35
# ----------------------------------------------------------
# After epoch 61 | valid err rate:  1.70% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  23900  | loss  0.00 | err rate  0.00%, steps/s 6347.14
# Minibatch  24000  | loss  0.00 | err rate  0.00%, steps/s 12797.93
# Minibatch  24100  | loss  0.00 | err rate  0.00%, steps/s 13014.81
# Minibatch  24200  | loss  0.00 | err rate  0.00%, steps/s 12748.25
# ----------------------------------------------------------
# After epoch 62 | valid err rate:  1.63% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  24300  | loss  0.00 | err rate  0.00%, steps/s 6336.56
# Minibatch  24400  | loss  0.00 | err rate  0.00%, steps/s 13130.86
# Minibatch  24500  | loss  0.00 | err rate  0.00%, steps/s 13105.75
# Minibatch  24600  | loss  0.00 | err rate  0.00%, steps/s 13322.44
# ----------------------------------------------------------
# After epoch 63 | valid err rate:  1.67% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  24700  | loss  0.00 | err rate  0.00%, steps/s 6499.45
# Minibatch  24800  | loss  0.00 | err rate  0.00%, steps/s 13194.39
# Minibatch  24900  | loss  0.00 | err rate  0.00%, steps/s 13306.01
# Minibatch  25000  | loss  0.00 | err rate  0.00%, steps/s 13590.97
# ----------------------------------------------------------
# After epoch 64 | valid err rate:  1.70% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  25100  | loss  0.00 | err rate  0.00%, steps/s 6756.14
# Minibatch  25200  | loss  0.00 | err rate  0.00%, steps/s 13766.48
# Minibatch  25300  | loss  0.00 | err rate  0.00%, steps/s 13827.92
# Minibatch  25400  | loss  0.00 | err rate  0.00%, steps/s 13909.84
# ----------------------------------------------------------
# After epoch 65 | valid err rate:  1.68% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  25500  | loss  0.00 | err rate  0.00%, steps/s 6757.35
# Minibatch  25600  | loss  0.00 | err rate  0.00%, steps/s 13904.11
# Minibatch  25700  | loss  0.00 | err rate  0.00%, steps/s 13776.63
# Minibatch  25800  | loss  0.00 | err rate  0.00%, steps/s 15160.66
# ----------------------------------------------------------
# After epoch 66 | valid err rate:  1.64% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  25900  | loss  0.00 | err rate  0.00%, steps/s 6625.77
# Minibatch  26000  | loss  0.00 | err rate  0.00%, steps/s 13931.25
# Minibatch  26100  | loss  0.00 | err rate  0.00%, steps/s 14001.74
# ----------------------------------------------------------
# After epoch 67 | valid err rate:  1.66% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  26200  | loss  0.00 | err rate  0.00%, steps/s 7161.70
# Minibatch  26300  | loss  0.00 | err rate  0.00%, steps/s 13226.14
# Minibatch  26400  | loss  0.00 | err rate  0.00%, steps/s 14088.48
# Minibatch  26500  | loss  0.00 | err rate  0.00%, steps/s 14344.61
# ----------------------------------------------------------
# After epoch 68 | valid err rate:  1.70% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  26600  | loss  0.00 | err rate  0.00%, steps/s 7012.16
# Minibatch  26700  | loss  0.00 | err rate  0.00%, steps/s 14220.53
# Minibatch  26800  | loss  0.00 | err rate  0.00%, steps/s 14495.91
# Minibatch  26900  | loss  0.00 | err rate  0.00%, steps/s 14265.37
# ----------------------------------------------------------
# After epoch 69 | valid err rate:  1.66% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  27000  | loss  0.00 | err rate  0.00%, steps/s 7235.76
# Minibatch  27100  | loss  0.00 | err rate  0.00%, steps/s 14414.20
# Minibatch  27200  | loss  0.00 | err rate  0.00%, steps/s 14311.86
# Minibatch  27300  | loss  0.01 | err rate  0.00%, steps/s 14402.95
# ----------------------------------------------------------
# After epoch 70 | valid err rate:  1.65% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  27400  | loss  0.00 | err rate  0.00%, steps/s 7270.31
# Minibatch  27500  | loss  0.00 | err rate  0.00%, steps/s 14775.99
# Minibatch  27600  | loss  0.01 | err rate  0.00%, steps/s 14975.75
# Minibatch  27700  | loss  0.00 | err rate  0.00%, steps/s 14773.08
# ----------------------------------------------------------
# After epoch 71 | valid err rate:  1.74% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  27800  | loss  0.01 | err rate  0.00%, steps/s 7403.15
# Minibatch  27900  | loss  0.00 | err rate  0.00%, steps/s 15159.62
# Minibatch  28000  | loss  0.00 | err rate  0.00%, steps/s 14994.97
# Minibatch  28100  | loss  0.00 | err rate  0.00%, steps/s 14976.32
# ----------------------------------------------------------
# After epoch 72 | valid err rate:  1.67% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  28200  | loss  0.00 | err rate  0.00%, steps/s 7350.09
# Minibatch  28300  | loss  0.00 | err rate  0.00%, steps/s 14942.12
# Minibatch  28400  | loss  0.00 | err rate  0.00%, steps/s 14871.85
# Minibatch  28500  | loss  0.00 | err rate  0.00%, steps/s 15141.63
# ----------------------------------------------------------
# After epoch 73 | valid err rate:  1.69% | doing  82 epochs
# ----------------------------------------------------------
# Minibatch  28600  | loss  0.01 | err rate  0.00%, steps/s 7517.08
# Minibatch  28700  | loss  0.01 | err rate  0.00%, steps/s 15134.13
# Minibatch  28800  | loss  0.00 | err rate  0.00%, steps/s 15544.89
# Minibatch  28900  | loss  0.00 | err rate  0.00%, steps/s 15245.68
# ----------------------------------------------------------
# After epoch 74 | valid err rate:  1.56% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  29000  | loss  0.01 | err rate  0.00%, steps/s 7589.48
# Minibatch  29100  | loss  0.00 | err rate  0.00%, steps/s 15762.55
# Minibatch  29200  | loss  0.01 | err rate  0.00%, steps/s 15450.45
# Minibatch  29300  | loss  0.00 | err rate  0.00%, steps/s 15725.82
# ----------------------------------------------------------
# After epoch 75 | valid err rate:  1.67% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  29400  | loss  0.00 | err rate  0.00%, steps/s 7831.62
# Minibatch  29500  | loss  0.01 | err rate  0.00%, steps/s 15774.60
# Minibatch  29600  | loss  0.00 | err rate  0.00%, steps/s 15894.02
# Minibatch  29700  | loss  0.00 | err rate  0.00%, steps/s 16036.64
# ----------------------------------------------------------
# After epoch 76 | valid err rate:  1.63% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  29800  | loss  0.00 | err rate  0.00%, steps/s 7820.03
# Minibatch  29900  | loss  0.00 | err rate  0.00%, steps/s 15858.68
# Minibatch  30000  | loss  0.00 | err rate  0.00%, steps/s 15944.78
# Minibatch  30100  | loss  0.00 | err rate  0.00%, steps/s 17029.89
# ----------------------------------------------------------
# After epoch 77 | valid err rate:  1.63% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  30200  | loss  0.00 | err rate  0.00%, steps/s 7649.40
# Minibatch  30300  | loss  0.00 | err rate  0.00%, steps/s 16246.24
# Minibatch  30400  | loss  0.01 | err rate  0.00%, steps/s 16133.70
# ----------------------------------------------------------
# After epoch 78 | valid err rate:  1.61% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  30500  | loss  0.00 | err rate  0.00%, steps/s 8093.54
# Minibatch  30600  | loss  0.00 | err rate  0.00%, steps/s 16046.62
# Minibatch  30700  | loss  0.00 | err rate  0.00%, steps/s 16282.05
# Minibatch  30800  | loss  0.00 | err rate  0.00%, steps/s 16103.01
# ----------------------------------------------------------
# After epoch 79 | valid err rate:  1.67% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  30900  | loss  0.00 | err rate  0.00%, steps/s 8270.65
# Minibatch  31000  | loss  0.00 | err rate  0.00%, steps/s 16618.11
# Minibatch  31100  | loss  0.00 | err rate  0.00%, steps/s 16501.82
# Minibatch  31200  | loss  0.00 | err rate  0.00%, steps/s 16898.57
# ----------------------------------------------------------
# After epoch 80 | valid err rate:  1.62% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  31300  | loss  0.00 | err rate  0.00%, steps/s 8339.75
# Minibatch  31400  | loss  0.00 | err rate  0.00%, steps/s 16976.59
# Minibatch  31500  | loss  0.00 | err rate  0.00%, steps/s 16806.97
# Minibatch  31600  | loss  0.00 | err rate  0.00%, steps/s 16985.37
# ----------------------------------------------------------
# After epoch 81 | valid err rate:  1.63% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  31700  | loss  0.00 | err rate  0.00%, steps/s 8521.00
# Minibatch  31800  | loss  0.00 | err rate  0.00%, steps/s 16827.87
# Minibatch  31900  | loss  0.01 | err rate  0.00%, steps/s 17003.57
# Minibatch  32000  | loss  0.00 | err rate  0.00%, steps/s 17291.81
# ----------------------------------------------------------
# After epoch 82 | valid err rate:  1.60% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  32100  | loss  0.00 | err rate  0.00%, steps/s 8525.74
# Minibatch  32200  | loss  0.00 | err rate  0.00%, steps/s 17890.54
# Minibatch  32300  | loss  0.00 | err rate  0.00%, steps/s 16839.61
# Minibatch  32400  | loss  0.00 | err rate  0.00%, steps/s 17885.48
# ----------------------------------------------------------
# After epoch 83 | valid err rate:  1.61% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  32500  | loss  0.00 | err rate  0.00%, steps/s 8567.80
# Minibatch  32600  | loss  0.00 | err rate  0.00%, steps/s 17753.79
# Minibatch  32700  | loss  0.00 | err rate  0.00%, steps/s 17446.82
# Minibatch  32800  | loss  0.00 | err rate  0.00%, steps/s 17834.58
# ----------------------------------------------------------
# After epoch 84 | valid err rate:  1.62% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  32900  | loss  0.00 | err rate  0.00%, steps/s 8736.11
# Minibatch  33000  | loss  0.00 | err rate  0.00%, steps/s 17544.80
# Minibatch  33100  | loss  0.00 | err rate  0.00%, steps/s 17759.01
# Minibatch  33200  | loss  0.00 | err rate  0.00%, steps/s 17890.84
# ----------------------------------------------------------
# After epoch 85 | valid err rate:  1.69% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  33300  | loss  0.00 | err rate  0.00%, steps/s 8886.84
# Minibatch  33400  | loss  0.00 | err rate  0.00%, steps/s 18090.03
# Minibatch  33500  | loss  0.00 | err rate  0.00%, steps/s 17886.50
# Minibatch  33600  | loss  0.00 | err rate  0.00%, steps/s 18073.08
# ----------------------------------------------------------
# After epoch 86 | valid err rate:  1.66% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  33700  | loss  0.00 | err rate  0.00%, steps/s 9058.97
# Minibatch  33800  | loss  0.00 | err rate  0.00%, steps/s 17921.92
# Minibatch  33900  | loss  0.00 | err rate  0.00%, steps/s 18121.00
# Minibatch  34000  | loss  0.00 | err rate  0.00%, steps/s 18429.38
# ----------------------------------------------------------
# After epoch 87 | valid err rate:  1.60% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  34100  | loss  0.00 | err rate  0.00%, steps/s 9032.21
# Minibatch  34200  | loss  0.00 | err rate  0.00%, steps/s 18177.83
# Minibatch  34300  | loss  0.00 | err rate  0.00%, steps/s 18415.64
# Minibatch  34400  | loss  0.00 | err rate  0.00%, steps/s 19716.73
# ----------------------------------------------------------
# After epoch 88 | valid err rate:  1.65% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  34500  | loss  0.00 | err rate  0.00%, steps/s 8930.67
# Minibatch  34600  | loss  0.00 | err rate  0.00%, steps/s 18676.89
# Minibatch  34700  | loss  0.00 | err rate  0.00%, steps/s 18852.21
# ----------------------------------------------------------
# After epoch 89 | valid err rate:  1.64% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  34800  | loss  0.00 | err rate  0.00%, steps/s 9822.72
# Minibatch  34900  | loss  0.00 | err rate  0.00%, steps/s 16957.54
# Minibatch  35000  | loss  0.00 | err rate  0.00%, steps/s 18570.69
# Minibatch  35100  | loss  0.00 | err rate  0.00%, steps/s 18952.82
# ----------------------------------------------------------
# After epoch 90 | valid err rate:  1.58% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  35200  | loss  0.00 | err rate  0.00%, steps/s 9490.39
# Minibatch  35300  | loss  0.00 | err rate  0.00%, steps/s 19282.36
# Minibatch  35400  | loss  0.00 | err rate  0.00%, steps/s 18966.62
# Minibatch  35500  | loss  0.00 | err rate  0.00%, steps/s 18593.80
# ----------------------------------------------------------
# After epoch 91 | valid err rate:  1.62% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  35600  | loss  0.00 | err rate  0.00%, steps/s 9439.36
# Minibatch  35700  | loss  0.00 | err rate  0.00%, steps/s 19406.67
# Minibatch  35800  | loss  0.00 | err rate  0.00%, steps/s 18499.96
# Minibatch  35900  | loss  0.00 | err rate  0.00%, steps/s 19062.42
# ----------------------------------------------------------
# After epoch 92 | valid err rate:  1.66% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  36000  | loss  0.00 | err rate  0.00%, steps/s 9423.92
# Minibatch  36100  | loss  0.00 | err rate  0.00%, steps/s 19501.46
# Minibatch  36200  | loss  0.00 | err rate  0.00%, steps/s 19139.60
# Minibatch  36300  | loss  0.00 | err rate  0.00%, steps/s 19415.87
# ----------------------------------------------------------
# After epoch 93 | valid err rate:  1.66% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  36400  | loss  0.00 | err rate  0.00%, steps/s 9715.49
# Minibatch  36500  | loss  0.00 | err rate  0.00%, steps/s 19798.76
# Minibatch  36600  | loss  0.01 | err rate  0.00%, steps/s 19683.25
# Minibatch  36700  | loss  0.00 | err rate  0.00%, steps/s 19558.06
# ----------------------------------------------------------
# After epoch 94 | valid err rate:  1.62% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  36800  | loss  0.00 | err rate  0.00%, steps/s 9885.22
# Minibatch  36900  | loss  0.00 | err rate  0.00%, steps/s 19790.81
# Minibatch  37000  | loss  0.00 | err rate  0.00%, steps/s 19768.13
# Minibatch  37100  | loss  0.00 | err rate  0.00%, steps/s 19765.12
# ----------------------------------------------------------
# After epoch 95 | valid err rate:  1.68% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  37200  | loss  0.00 | err rate  0.00%, steps/s 9848.11
# Minibatch  37300  | loss  0.00 | err rate  0.00%, steps/s 20096.79
# Minibatch  37400  | loss  0.00 | err rate  0.00%, steps/s 19805.05
# Minibatch  37500  | loss  0.00 | err rate  0.00%, steps/s 20272.03
# ----------------------------------------------------------
# After epoch 96 | valid err rate:  1.63% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  37600  | loss  0.00 | err rate  0.00%, steps/s 10031.68
# Minibatch  37700  | loss  0.00 | err rate  0.00%, steps/s 19713.97
# Minibatch  37800  | loss  0.00 | err rate  0.00%, steps/s 20202.02
# Minibatch  37900  | loss  0.00 | err rate  0.00%, steps/s 19998.86
# ----------------------------------------------------------
# After epoch 97 | valid err rate:  1.66% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  38000  | loss  0.00 | err rate  0.00%, steps/s 10023.72
# Minibatch  38100  | loss  0.00 | err rate  0.00%, steps/s 19958.77
# Minibatch  38200  | loss  0.00 | err rate  0.00%, steps/s 20708.07
# Minibatch  38300  | loss  0.00 | err rate  0.00%, steps/s 20185.46
# ----------------------------------------------------------
# After epoch 98 | valid err rate:  1.60% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  38400  | loss  0.00 | err rate  0.00%, steps/s 10129.92
# Minibatch  38500  | loss  0.00 | err rate  0.00%, steps/s 20591.22
# Minibatch  38600  | loss  0.00 | err rate  0.00%, steps/s 20781.29
# Minibatch  38700  | loss  0.00 | err rate  0.00%, steps/s 22279.66
# ----------------------------------------------------------
# After epoch 99 | valid err rate:  1.63% | doing 112 epochs
# ----------------------------------------------------------
# Minibatch  38800  | loss  0.00 | err rate  0.00%, steps/s 10128.03
# Minibatch  38900  | loss  0.00 | err rate  0.00%, steps/s 21127.50
# Minibatch  39000  | loss  0.00 | err rate  0.00%, steps/s 21279.04
# Minibatch  39100  | loss  0.00 | err rate  0.00%, steps/s 24125.45
# -----------------------------------------------------------
# After epoch 100 | valid err rate:  1.61% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  39200  | loss  0.00 | err rate  0.00%, steps/s 9977.70
# Minibatch  39300  | loss  0.00 | err rate  0.00%, steps/s 21270.71
# Minibatch  39400  | loss  0.00 | err rate  0.00%, steps/s 21592.49
# -----------------------------------------------------------
# After epoch 101 | valid err rate:  1.61% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  39500  | loss  0.00 | err rate  0.00%, steps/s 10809.04
# Minibatch  39600  | loss  0.00 | err rate  0.00%, steps/s 20618.63
# Minibatch  39700  | loss  0.00 | err rate  0.00%, steps/s 21271.98
# Minibatch  39800  | loss  0.00 | err rate  0.00%, steps/s 21474.68
# -----------------------------------------------------------
# After epoch 102 | valid err rate:  1.62% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  39900  | loss  0.00 | err rate  0.00%, steps/s 10587.41
# Minibatch  40000  | loss  0.00 | err rate  0.00%, steps/s 21466.33
# Minibatch  40100  | loss  0.00 | err rate  0.00%, steps/s 21691.12
# Minibatch  40200  | loss  0.00 | err rate  0.00%, steps/s 21724.24
# -----------------------------------------------------------
# After epoch 103 | valid err rate:  1.56% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  40300  | loss  0.00 | err rate  0.00%, steps/s 10737.72
# Minibatch  40400  | loss  0.00 | err rate  0.00%, steps/s 21963.64
# Minibatch  40500  | loss  0.01 | err rate  0.00%, steps/s 22029.95
# Minibatch  40600  | loss  0.01 | err rate  0.00%, steps/s 21735.90
# -----------------------------------------------------------
# After epoch 104 | valid err rate:  1.62% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  40700  | loss  0.01 | err rate  0.00%, steps/s 10862.79
# Minibatch  40800  | loss  0.00 | err rate  0.00%, steps/s 21947.57
# Minibatch  40900  | loss  0.00 | err rate  0.00%, steps/s 21723.55
# Minibatch  41000  | loss  0.00 | err rate  0.00%, steps/s 22193.30
# -----------------------------------------------------------
# After epoch 105 | valid err rate:  1.61% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  41100  | loss  0.00 | err rate  0.00%, steps/s 10821.15
# Minibatch  41200  | loss  0.00 | err rate  0.00%, steps/s 21780.92
# Minibatch  41300  | loss  0.00 | err rate  0.00%, steps/s 22123.48
# Minibatch  41400  | loss  0.00 | err rate  0.00%, steps/s 21967.29
# -----------------------------------------------------------
# After epoch 106 | valid err rate:  1.64% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  41500  | loss  0.00 | err rate  0.00%, steps/s 11027.23
# Minibatch  41600  | loss  0.00 | err rate  0.00%, steps/s 22158.69
# Minibatch  41700  | loss  0.00 | err rate  0.00%, steps/s 22585.37
# Minibatch  41800  | loss  0.01 | err rate  0.00%, steps/s 22043.38
# -----------------------------------------------------------
# After epoch 107 | valid err rate:  1.70% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  41900  | loss  0.01 | err rate  0.00%, steps/s 11043.94
# Minibatch  42000  | loss  0.00 | err rate  0.00%, steps/s 22189.67
# Minibatch  42100  | loss  0.00 | err rate  0.00%, steps/s 21994.77
# Minibatch  42200  | loss  0.01 | err rate  0.00%, steps/s 22061.80
# -----------------------------------------------------------
# After epoch 108 | valid err rate:  1.66% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  42300  | loss  0.00 | err rate  0.00%, steps/s 11238.48
# Minibatch  42400  | loss  0.00 | err rate  0.00%, steps/s 22529.48
# Minibatch  42500  | loss  0.00 | err rate  0.00%, steps/s 22273.40
# Minibatch  42600  | loss  0.00 | err rate  0.00%, steps/s 22783.85
# -----------------------------------------------------------
# After epoch 109 | valid err rate:  1.59% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  42700  | loss  0.00 | err rate  0.00%, steps/s 11209.35
# Minibatch  42800  | loss  0.00 | err rate  0.00%, steps/s 23028.18
# Minibatch  42900  | loss  0.00 | err rate  0.00%, steps/s 22530.87
# Minibatch  43000  | loss  0.01 | err rate  0.00%, steps/s 24360.22
# -----------------------------------------------------------
# After epoch 110 | valid err rate:  1.64% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  43100  | loss  0.01 | err rate  0.00%, steps/s 11128.29
# Minibatch  43200  | loss  0.00 | err rate  0.00%, steps/s 22665.03
# Minibatch  43300  | loss  0.00 | err rate  0.00%, steps/s 23055.54
# Minibatch  43400  | loss  0.00 | err rate  0.00%, steps/s 26705.25
# -----------------------------------------------------------
# After epoch 111 | valid err rate:  1.63% | doing 112 epochs
# -----------------------------------------------------------
# Minibatch  43500  | loss  0.00 | err rate  0.00%, steps/s 10856.70
# Minibatch  43600  | loss  0.00 | err rate  0.00%, steps/s 22835.90
# Minibatch  43700  | loss  0.00 | err rate  0.00%, steps/s 23251.36
# -----------------------------------------------------------
# After epoch 112 | valid err rate:  1.61% | doing 112 epochs
# -----------------------------------------------------------
#
# Loading best params on validation set (epoch 74)
#
# Test error rate: 1.73%

# %% [markdown]
# # Problem 3: Dropout [2p]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout. The best
# results with dropout are below 1%!
#
# Remember to turn off dropout during testing, using `model.train_mode()` and `model.eval_mode()`!
#
# Hint: Use [torch.nn.functional.dropout](http://pytorch.org/docs/master/nn.html#torch.nn.functional.dropout).
#
# Details: http://arxiv.org/pdf/1207.0580.pdf.

# %%
class DropoutLayer(Layer):
    def __init__(self, p):
      self.p = p
      
    def forward(self, x):
        factor = 1 / self.p if self.training else 1
        return F.dropout(x, p = self.p, training=self.training) * factor
    
class  LeakyReLULayer(Layer):
    def forward(self, x):
        return F.leaky_relu(x)


model = FeedforwardNet(
    [
     AffineLayer(784, 1300),
     DropoutLayer(0.5),
     LeakyReLULayer(),
     AffineLayer(1300, 10),
     SoftMaxLayer()
    ])


with torch.no_grad():
    # Initialize parameters
    for name, p in model.parameters:
        if name == 'W':
            torch.nn.init.xavier_normal_(p)
        elif name == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

SGD(model, mnist_loaders, alpha=0.055, device='cuda')

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.28 | err rate  7.81%, steps/s 59.95
# Minibatch    200  | loss  0.19 | err rate  6.25%, steps/s 140.67
# Minibatch    300  | loss  0.15 | err rate  6.25%, steps/s 166.87
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  3.56% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.17 | err rate  3.12%, steps/s 114.07
# Minibatch    500  | loss  0.13 | err rate  4.69%, steps/s 270.34
# Minibatch    600  | loss  0.10 | err rate  3.91%, steps/s 335.75
# Minibatch    700  | loss  0.15 | err rate  3.91%, steps/s 392.29
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.91% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.15 | err rate  5.47%, steps/s 224.34
# Minibatch    900  | loss  0.05 | err rate  0.78%, steps/s 493.62
# Minibatch   1000  | loss  0.04 | err rate  1.56%, steps/s 545.12
# Minibatch   1100  | loss  0.10 | err rate  3.12%, steps/s 624.97
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.51% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.13 | err rate  2.34%, steps/s 332.95
# Minibatch   1300  | loss  0.05 | err rate  0.78%, steps/s 716.77
# Minibatch   1400  | loss  0.10 | err rate  1.56%, steps/s 774.69
# Minibatch   1500  | loss  0.07 | err rate  2.34%, steps/s 833.84
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.13% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.04 | err rate  0.00%, steps/s 447.12
# Minibatch   1700  | loss  0.07 | err rate  3.12%, steps/s 952.12
# Minibatch   1800  | loss  0.05 | err rate  1.56%, steps/s 1000.38
# Minibatch   1900  | loss  0.10 | err rate  3.12%, steps/s 1043.11
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  2.24% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.06 | err rate  2.34%, steps/s 555.50
# Minibatch   2100  | loss  0.07 | err rate  1.56%, steps/s 1174.25
# Minibatch   2200  | loss  0.05 | err rate  0.78%, steps/s 1214.84
# Minibatch   2300  | loss  0.06 | err rate  0.78%, steps/s 1262.21
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  2.12% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.05 | err rate  0.78%, steps/s 668.44
# Minibatch   2500  | loss  0.13 | err rate  3.12%, steps/s 1422.46
# Minibatch   2600  | loss  0.02 | err rate  0.00%, steps/s 1464.01
# Minibatch   2700  | loss  0.16 | err rate  5.47%, steps/s 1546.99
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.91% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.09 | err rate  1.56%, steps/s 786.53
# Minibatch   2900  | loss  0.09 | err rate  3.12%, steps/s 1607.40
# Minibatch   3000  | loss  0.06 | err rate  1.56%, steps/s 1696.47
# Minibatch   3100  | loss  0.02 | err rate  0.00%, steps/s 1715.40
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.88% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.03 | err rate  0.00%, steps/s 886.89
# Minibatch   3300  | loss  0.04 | err rate  1.56%, steps/s 1886.22
# Minibatch   3400  | loss  0.04 | err rate  1.56%, steps/s 1868.74
# Minibatch   3500  | loss  0.02 | err rate  0.00%, steps/s 1926.96
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.90% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.03 | err rate  1.56%, steps/s 998.36
# Minibatch   3700  | loss  0.01 | err rate  0.00%, steps/s 2088.39
# Minibatch   3800  | loss  0.05 | err rate  0.78%, steps/s 2187.39
# Minibatch   3900  | loss  0.02 | err rate  0.78%, steps/s 2290.76
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.82% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.03 | err rate  0.78%, steps/s 1063.34
# Minibatch   4100  | loss  0.05 | err rate  1.56%, steps/s 2270.59
# Minibatch   4200  | loss  0.03 | err rate  0.78%, steps/s 2317.58
# Minibatch   4300  | loss  0.02 | err rate  0.78%, steps/s 2772.51
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.80% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.01 | err rate  0.00%, steps/s 1133.76
# Minibatch   4500  | loss  0.02 | err rate  0.78%, steps/s 2491.21
# Minibatch   4600  | loss  0.01 | err rate  0.00%, steps/s 2552.88
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.76% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.03 | err rate  1.56%, steps/s 1335.26
# Minibatch   4800  | loss  0.02 | err rate  0.00%, steps/s 2504.37
# Minibatch   4900  | loss  0.01 | err rate  0.00%, steps/s 2717.24
# Minibatch   5000  | loss  0.02 | err rate  0.00%, steps/s 2793.03
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.85% | doing  19 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.02 | err rate  1.56%, steps/s 1410.90
# Minibatch   5200  | loss  0.01 | err rate  0.00%, steps/s 2881.27
# Minibatch   5300  | loss  0.02 | err rate  0.78%, steps/s 2909.99
# Minibatch   5400  | loss  0.02 | err rate  0.00%, steps/s 3021.91
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.70% | doing  22 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.02 | err rate  0.78%, steps/s 1523.77
# Minibatch   5600  | loss  0.04 | err rate  1.56%, steps/s 3078.12
# Minibatch   5700  | loss  0.02 | err rate  0.00%, steps/s 3175.40
# Minibatch   5800  | loss  0.01 | err rate  0.00%, steps/s 3186.44
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.66% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.02 | err rate  0.00%, steps/s 1628.56
# Minibatch   6000  | loss  0.01 | err rate  0.78%, steps/s 3383.08
# Minibatch   6100  | loss  0.05 | err rate  1.56%, steps/s 3336.84
# Minibatch   6200  | loss  0.02 | err rate  0.78%, steps/s 3458.84
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.65% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.03 | err rate  0.78%, steps/s 1751.51
# Minibatch   6400  | loss  0.02 | err rate  0.78%, steps/s 3520.76
# Minibatch   6500  | loss  0.03 | err rate  0.78%, steps/s 3634.07
# Minibatch   6600  | loss  0.02 | err rate  1.56%, steps/s 3637.24
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.65% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.01 | err rate  0.00%, steps/s 1862.60
# Minibatch   6800  | loss  0.07 | err rate  3.12%, steps/s 3761.13
# Minibatch   6900  | loss  0.04 | err rate  1.56%, steps/s 3838.39
# Minibatch   7000  | loss  0.01 | err rate  0.00%, steps/s 3929.63
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.67% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.02 | err rate  0.78%, steps/s 1939.41
# Minibatch   7200  | loss  0.01 | err rate  0.00%, steps/s 4014.36
# Minibatch   7300  | loss  0.01 | err rate  0.00%, steps/s 4012.27
# Minibatch   7400  | loss  0.03 | err rate  1.56%, steps/s 4138.38
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.62% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.01 | err rate  0.00%, steps/s 2059.03
# Minibatch   7600  | loss  0.02 | err rate  0.78%, steps/s 4133.67
# Minibatch   7700  | loss  0.02 | err rate  0.78%, steps/s 4229.65
# Minibatch   7800  | loss  0.02 | err rate  0.78%, steps/s 4388.02
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.74% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.01 | err rate  0.78%, steps/s 2175.19
# Minibatch   8000  | loss  0.01 | err rate  0.00%, steps/s 4430.23
# Minibatch   8100  | loss  0.02 | err rate  0.78%, steps/s 4456.82
# Minibatch   8200  | loss  0.03 | err rate  0.00%, steps/s 4907.26
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  1.65% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.01 | err rate  0.78%, steps/s 2233.96
# Minibatch   8400  | loss  0.03 | err rate  0.78%, steps/s 4543.50
# Minibatch   8500  | loss  0.04 | err rate  1.56%, steps/s 4790.26
# Minibatch   8600  | loss  0.01 | err rate  0.00%, steps/s 5417.35
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.65% | doing  29 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.01 | err rate  0.00%, steps/s 2267.83
# Minibatch   8800  | loss  0.02 | err rate  0.00%, steps/s 4869.09
# Minibatch   8900  | loss  0.00 | err rate  0.00%, steps/s 4814.09
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.53% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.02 | err rate  0.78%, steps/s 2534.49
# Minibatch   9100  | loss  0.02 | err rate  0.78%, steps/s 4916.78
# Minibatch   9200  | loss  0.01 | err rate  0.00%, steps/s 5119.84
# Minibatch   9300  | loss  0.01 | err rate  0.00%, steps/s 5172.01
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.62% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.01 | err rate  0.00%, steps/s 2632.07
# Minibatch   9500  | loss  0.01 | err rate  0.00%, steps/s 5142.84
# Minibatch   9600  | loss  0.03 | err rate  1.56%, steps/s 5305.69
# Minibatch   9700  | loss  0.01 | err rate  0.78%, steps/s 5456.78
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  1.63% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.02 | err rate  0.00%, steps/s 2707.97
# Minibatch   9900  | loss  0.02 | err rate  0.00%, steps/s 5500.74
# Minibatch  10000  | loss  0.01 | err rate  0.78%, steps/s 5626.58
# Minibatch  10100  | loss  0.01 | err rate  0.00%, steps/s 5497.70
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  1.67% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.01 | err rate  0.00%, steps/s 2808.18
# Minibatch  10300  | loss  0.03 | err rate  0.78%, steps/s 5785.54
# Minibatch  10400  | loss  0.03 | err rate  0.78%, steps/s 5783.23
# Minibatch  10500  | loss  0.03 | err rate  0.00%, steps/s 5708.02
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.61% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.02 | err rate  0.78%, steps/s 2928.92
# Minibatch  10700  | loss  0.01 | err rate  0.00%, steps/s 5859.13
# Minibatch  10800  | loss  0.01 | err rate  0.00%, steps/s 5988.80
# Minibatch  10900  | loss  0.01 | err rate  0.00%, steps/s 6015.30
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.64% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.01 | err rate  0.78%, steps/s 3056.17
# Minibatch  11100  | loss  0.01 | err rate  0.00%, steps/s 6086.15
# Minibatch  11200  | loss  0.02 | err rate  0.00%, steps/s 6223.96
# Minibatch  11300  | loss  0.03 | err rate  0.78%, steps/s 6407.24
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.63% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  11400  | loss  0.01 | err rate  0.00%, steps/s 3129.56
# Minibatch  11500  | loss  0.01 | err rate  0.00%, steps/s 6348.58
# Minibatch  11600  | loss  0.02 | err rate  0.00%, steps/s 6473.08
# Minibatch  11700  | loss  0.01 | err rate  0.78%, steps/s 6501.69
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.68% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.00 | err rate  0.00%, steps/s 3282.76
# Minibatch  11900  | loss  0.01 | err rate  0.00%, steps/s 6641.50
# Minibatch  12000  | loss  0.04 | err rate  1.56%, steps/s 6686.84
# Minibatch  12100  | loss  0.01 | err rate  0.00%, steps/s 6719.12
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.61% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  12200  | loss  0.01 | err rate  0.00%, steps/s 3415.44
# Minibatch  12300  | loss  0.02 | err rate  0.78%, steps/s 6782.21
# Minibatch  12400  | loss  0.01 | err rate  0.00%, steps/s 6826.21
# Minibatch  12500  | loss  0.01 | err rate  0.00%, steps/s 7361.12
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  1.64% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.01 | err rate  0.78%, steps/s 3380.59
# Minibatch  12700  | loss  0.00 | err rate  0.00%, steps/s 7113.99
# Minibatch  12800  | loss  0.01 | err rate  0.00%, steps/s 7058.34
# Minibatch  12900  | loss  0.01 | err rate  0.00%, steps/s 8164.06
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  1.64% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  13000  | loss  0.01 | err rate  0.78%, steps/s 3396.56
# Minibatch  13100  | loss  0.02 | err rate  1.56%, steps/s 7270.81
# Minibatch  13200  | loss  0.03 | err rate  1.56%, steps/s 7356.47
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  1.59% | doing  35 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.00 | err rate  0.00%, steps/s 3793.35
# Minibatch  13400  | loss  0.01 | err rate  0.00%, steps/s 7017.73
# Minibatch  13500  | loss  0.01 | err rate  0.00%, steps/s 7349.93
# Minibatch  13600  | loss  0.02 | err rate  0.78%, steps/s 7592.14
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  1.51% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  13700  | loss  0.00 | err rate  0.00%, steps/s 3823.93
# Minibatch  13800  | loss  0.01 | err rate  0.78%, steps/s 7415.30
# Minibatch  13900  | loss  0.01 | err rate  0.00%, steps/s 7936.37
# Minibatch  14000  | loss  0.00 | err rate  0.00%, steps/s 7658.54
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  1.57% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.02 | err rate  0.00%, steps/s 3894.30
# Minibatch  14200  | loss  0.01 | err rate  0.00%, steps/s 7816.35
# Minibatch  14300  | loss  0.01 | err rate  0.00%, steps/s 8050.27
# Minibatch  14400  | loss  0.02 | err rate  0.78%, steps/s 7970.15
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  1.53% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  14500  | loss  0.01 | err rate  0.00%, steps/s 4026.00
# Minibatch  14600  | loss  0.01 | err rate  0.00%, steps/s 8074.52
# Minibatch  14700  | loss  0.02 | err rate  1.56%, steps/s 8042.36
# Minibatch  14800  | loss  0.01 | err rate  0.00%, steps/s 8227.30
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  1.59% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.01 | err rate  0.00%, steps/s 4172.85
# Minibatch  15000  | loss  0.02 | err rate  0.78%, steps/s 8140.70
# Minibatch  15100  | loss  0.02 | err rate  0.78%, steps/s 8292.18
# Minibatch  15200  | loss  0.00 | err rate  0.00%, steps/s 8361.95
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  1.60% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  15300  | loss  0.00 | err rate  0.00%, steps/s 4231.86
# Minibatch  15400  | loss  0.02 | err rate  0.78%, steps/s 8518.94
# Minibatch  15500  | loss  0.01 | err rate  0.00%, steps/s 8580.42
# Minibatch  15600  | loss  0.01 | err rate  0.78%, steps/s 8742.85
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  1.56% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.01 | err rate  0.78%, steps/s 4328.02
# Minibatch  15800  | loss  0.00 | err rate  0.00%, steps/s 8720.25
# Minibatch  15900  | loss  0.01 | err rate  0.00%, steps/s 8860.67
# Minibatch  16000  | loss  0.01 | err rate  0.00%, steps/s 8890.18
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  1.52% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  16100  | loss  0.01 | err rate  0.00%, steps/s 4474.20
# Minibatch  16200  | loss  0.01 | err rate  0.00%, steps/s 9191.91
# Minibatch  16300  | loss  0.01 | err rate  0.00%, steps/s 9205.92
# Minibatch  16400  | loss  0.00 | err rate  0.00%, steps/s 9234.97
# ----------------------------------------------------------
# After epoch 42 | valid err rate:  1.49% | doing  64 epochs
# ----------------------------------------------------------
# Minibatch  16500  | loss  0.00 | err rate  0.00%, steps/s 4698.29
# Minibatch  16600  | loss  0.01 | err rate  0.00%, steps/s 9162.48
# Minibatch  16700  | loss  0.02 | err rate  0.78%, steps/s 9198.55
# Minibatch  16800  | loss  0.01 | err rate  0.78%, steps/s 9816.00
# ----------------------------------------------------------
# After epoch 43 | valid err rate:  1.58% | doing  64 epochs
# ----------------------------------------------------------
# Minibatch  16900  | loss  0.00 | err rate  0.00%, steps/s 4545.02
# Minibatch  17000  | loss  0.00 | err rate  0.00%, steps/s 9408.56
# Minibatch  17100  | loss  0.01 | err rate  0.00%, steps/s 9601.56
# Minibatch  17200  | loss  0.00 | err rate  0.00%, steps/s 10860.34
# ----------------------------------------------------------
# After epoch 44 | valid err rate:  1.58% | doing  64 epochs
# ----------------------------------------------------------
# Minibatch  17300  | loss  0.01 | err rate  0.00%, steps/s 4568.30
# Minibatch  17400  | loss  0.01 | err rate  0.00%, steps/s 9702.19
# Minibatch  17500  | loss  0.01 | err rate  0.00%, steps/s 9708.80
# ----------------------------------------------------------
# After epoch 45 | valid err rate:  1.50% | doing  64 epochs
# ----------------------------------------------------------
# Minibatch  17600  | loss  0.00 | err rate  0.00%, steps/s 4935.05
# Minibatch  17700  | loss  0.01 | err rate  0.00%, steps/s 9555.84
# Minibatch  17800  | loss  0.01 | err rate  0.00%, steps/s 9835.74
# Minibatch  17900  | loss  0.01 | err rate  0.78%, steps/s 10005.47
# ----------------------------------------------------------
# After epoch 46 | valid err rate:  1.48% | doing  70 epochs
# ----------------------------------------------------------
# Minibatch  18000  | loss  0.00 | err rate  0.00%, steps/s 4981.89
# Minibatch  18100  | loss  0.01 | err rate  0.00%, steps/s 10012.89
# Minibatch  18200  | loss  0.00 | err rate  0.00%, steps/s 9912.84
# Minibatch  18300  | loss  0.03 | err rate  1.56%, steps/s 10320.98
# ----------------------------------------------------------
# After epoch 47 | valid err rate:  1.44% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  18400  | loss  0.01 | err rate  0.00%, steps/s 5026.65
# Minibatch  18500  | loss  0.00 | err rate  0.00%, steps/s 10185.05
# Minibatch  18600  | loss  0.00 | err rate  0.00%, steps/s 10367.50
# Minibatch  18700  | loss  0.00 | err rate  0.00%, steps/s 10495.12
# ----------------------------------------------------------
# After epoch 48 | valid err rate:  1.52% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  18800  | loss  0.01 | err rate  0.00%, steps/s 5171.88
# Minibatch  18900  | loss  0.01 | err rate  0.00%, steps/s 10657.40
# Minibatch  19000  | loss  0.00 | err rate  0.00%, steps/s 10639.85
# Minibatch  19100  | loss  0.01 | err rate  0.00%, steps/s 10401.31
# ----------------------------------------------------------
# After epoch 49 | valid err rate:  1.47% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  19200  | loss  0.00 | err rate  0.00%, steps/s 5401.61
# Minibatch  19300  | loss  0.00 | err rate  0.00%, steps/s 10460.76
# Minibatch  19400  | loss  0.01 | err rate  0.00%, steps/s 10717.65
# Minibatch  19500  | loss  0.01 | err rate  0.00%, steps/s 10719.37
# ----------------------------------------------------------
# After epoch 50 | valid err rate:  1.52% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  19600  | loss  0.00 | err rate  0.00%, steps/s 5428.41
# Minibatch  19700  | loss  0.01 | err rate  0.00%, steps/s 10996.33
# Minibatch  19800  | loss  0.00 | err rate  0.00%, steps/s 11111.94
# Minibatch  19900  | loss  0.00 | err rate  0.00%, steps/s 10847.64
# ----------------------------------------------------------
# After epoch 51 | valid err rate:  1.52% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  20000  | loss  0.01 | err rate  0.00%, steps/s 5522.44
# Minibatch  20100  | loss  0.01 | err rate  0.00%, steps/s 11098.81
# Minibatch  20200  | loss  0.01 | err rate  0.00%, steps/s 11215.42
# Minibatch  20300  | loss  0.01 | err rate  0.00%, steps/s 11170.03
# ----------------------------------------------------------
# After epoch 52 | valid err rate:  1.53% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  20400  | loss  0.01 | err rate  0.00%, steps/s 5659.51
# Minibatch  20500  | loss  0.00 | err rate  0.00%, steps/s 11332.38
# Minibatch  20600  | loss  0.01 | err rate  0.00%, steps/s 11778.18
# Minibatch  20700  | loss  0.01 | err rate  0.78%, steps/s 11207.07
# ----------------------------------------------------------
# After epoch 53 | valid err rate:  1.51% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  20800  | loss  0.00 | err rate  0.00%, steps/s 5733.63
# Minibatch  20900  | loss  0.01 | err rate  0.00%, steps/s 11917.64
# Minibatch  21000  | loss  0.01 | err rate  0.00%, steps/s 11425.54
# Minibatch  21100  | loss  0.00 | err rate  0.00%, steps/s 12232.74
# ----------------------------------------------------------
# After epoch 54 | valid err rate:  1.47% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  21200  | loss  0.01 | err rate  0.00%, steps/s 5768.75
# Minibatch  21300  | loss  0.01 | err rate  0.78%, steps/s 11712.11
# Minibatch  21400  | loss  0.01 | err rate  0.00%, steps/s 12125.21
# Minibatch  21500  | loss  0.01 | err rate  0.78%, steps/s 13257.99
# ----------------------------------------------------------
# After epoch 55 | valid err rate:  1.46% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  21600  | loss  0.01 | err rate  0.00%, steps/s 5701.02
# Minibatch  21700  | loss  0.02 | err rate  0.78%, steps/s 12057.01
# Minibatch  21800  | loss  0.00 | err rate  0.00%, steps/s 12220.12
# ----------------------------------------------------------
# After epoch 56 | valid err rate:  1.51% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  21900  | loss  0.02 | err rate  0.78%, steps/s 6115.22
# Minibatch  22000  | loss  0.01 | err rate  0.00%, steps/s 12121.04
# Minibatch  22100  | loss  0.00 | err rate  0.00%, steps/s 12160.72
# Minibatch  22200  | loss  0.01 | err rate  0.00%, steps/s 12014.87
# ----------------------------------------------------------
# After epoch 57 | valid err rate:  1.49% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  22300  | loss  0.00 | err rate  0.00%, steps/s 6278.87
# Minibatch  22400  | loss  0.01 | err rate  0.00%, steps/s 12203.99
# Minibatch  22500  | loss  0.01 | err rate  0.00%, steps/s 12687.99
# Minibatch  22600  | loss  0.00 | err rate  0.00%, steps/s 12569.39
# ----------------------------------------------------------
# After epoch 58 | valid err rate:  1.46% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  22700  | loss  0.01 | err rate  0.00%, steps/s 6270.50
# Minibatch  22800  | loss  0.01 | err rate  0.00%, steps/s 12579.03
# Minibatch  22900  | loss  0.02 | err rate  0.78%, steps/s 12929.07
# Minibatch  23000  | loss  0.00 | err rate  0.00%, steps/s 12590.70
# ----------------------------------------------------------
# After epoch 59 | valid err rate:  1.47% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  23100  | loss  0.01 | err rate  0.00%, steps/s 6353.93
# Minibatch  23200  | loss  0.01 | err rate  0.00%, steps/s 13039.36
# Minibatch  23300  | loss  0.01 | err rate  0.78%, steps/s 12971.73
# Minibatch  23400  | loss  0.00 | err rate  0.00%, steps/s 12902.74
# ----------------------------------------------------------
# After epoch 60 | valid err rate:  1.53% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  23500  | loss  0.02 | err rate  0.00%, steps/s 6569.46
# Minibatch  23600  | loss  0.00 | err rate  0.00%, steps/s 12974.95
# Minibatch  23700  | loss  0.01 | err rate  0.00%, steps/s 13293.91
# Minibatch  23800  | loss  0.01 | err rate  0.00%, steps/s 13241.03
# ----------------------------------------------------------
# After epoch 61 | valid err rate:  1.47% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  23900  | loss  0.00 | err rate  0.00%, steps/s 6578.09
# Minibatch  24000  | loss  0.00 | err rate  0.00%, steps/s 13463.65
# Minibatch  24100  | loss  0.00 | err rate  0.00%, steps/s 13313.24
# Minibatch  24200  | loss  0.02 | err rate  0.78%, steps/s 13405.54
# ----------------------------------------------------------
# After epoch 62 | valid err rate:  1.49% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  24300  | loss  0.01 | err rate  0.78%, steps/s 6775.04
# Minibatch  24400  | loss  0.00 | err rate  0.00%, steps/s 13671.65
# Minibatch  24500  | loss  0.01 | err rate  0.00%, steps/s 13543.99
# Minibatch  24600  | loss  0.01 | err rate  0.00%, steps/s 13683.78
# ----------------------------------------------------------
# After epoch 63 | valid err rate:  1.48% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  24700  | loss  0.02 | err rate  0.78%, steps/s 6854.57
# Minibatch  24800  | loss  0.01 | err rate  0.00%, steps/s 13643.80
# Minibatch  24900  | loss  0.01 | err rate  0.00%, steps/s 14049.53
# Minibatch  25000  | loss  0.00 | err rate  0.00%, steps/s 13819.12
# ----------------------------------------------------------
# After epoch 64 | valid err rate:  1.48% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  25100  | loss  0.01 | err rate  0.00%, steps/s 6919.10
# Minibatch  25200  | loss  0.00 | err rate  0.00%, steps/s 13832.10
# Minibatch  25300  | loss  0.01 | err rate  0.00%, steps/s 14056.31
# Minibatch  25400  | loss  0.02 | err rate  0.78%, steps/s 14262.90
# ----------------------------------------------------------
# After epoch 65 | valid err rate:  1.50% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  25500  | loss  0.01 | err rate  0.00%, steps/s 6914.74
# Minibatch  25600  | loss  0.01 | err rate  0.00%, steps/s 14545.34
# Minibatch  25700  | loss  0.01 | err rate  0.00%, steps/s 13940.80
# Minibatch  25800  | loss  0.00 | err rate  0.00%, steps/s 15922.34
# ----------------------------------------------------------
# After epoch 66 | valid err rate:  1.63% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  25900  | loss  0.00 | err rate  0.00%, steps/s 6802.10
# Minibatch  26000  | loss  0.00 | err rate  0.00%, steps/s 14533.61
# Minibatch  26100  | loss  0.00 | err rate  0.00%, steps/s 14474.04
# ----------------------------------------------------------
# After epoch 67 | valid err rate:  1.51% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  26200  | loss  0.01 | err rate  0.00%, steps/s 7464.85
# Minibatch  26300  | loss  0.01 | err rate  0.00%, steps/s 13653.54
# Minibatch  26400  | loss  0.01 | err rate  0.00%, steps/s 14615.74
# Minibatch  26500  | loss  0.01 | err rate  0.00%, steps/s 14703.87
# ----------------------------------------------------------
# After epoch 68 | valid err rate:  1.50% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  26600  | loss  0.01 | err rate  0.00%, steps/s 7436.05
# Minibatch  26700  | loss  0.00 | err rate  0.00%, steps/s 14633.16
# Minibatch  26800  | loss  0.00 | err rate  0.00%, steps/s 14878.92
# Minibatch  26900  | loss  0.02 | err rate  0.78%, steps/s 15020.82
# ----------------------------------------------------------
# After epoch 69 | valid err rate:  1.52% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  27000  | loss  0.00 | err rate  0.00%, steps/s 7492.61
# Minibatch  27100  | loss  0.01 | err rate  0.78%, steps/s 15112.90
# Minibatch  27200  | loss  0.00 | err rate  0.00%, steps/s 15166.66
# Minibatch  27300  | loss  0.01 | err rate  0.00%, steps/s 15074.07
# ----------------------------------------------------------
# After epoch 70 | valid err rate:  1.56% | doing  71 epochs
# ----------------------------------------------------------
# Minibatch  27400  | loss  0.00 | err rate  0.00%, steps/s 7560.70
# Minibatch  27500  | loss  0.01 | err rate  0.00%, steps/s 15283.22
# Minibatch  27600  | loss  0.01 | err rate  0.00%, steps/s 15171.01
# Minibatch  27700  | loss  0.01 | err rate  0.00%, steps/s 15500.16
# ----------------------------------------------------------
# After epoch 71 | valid err rate:  1.55% | doing  71 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 47)
#
# Test error rate: 1.49%

# %% [markdown]
# # Problem 4: Data Augmentation [1p]
#
# Apply data augmentation methods (e.g. rotations, noise, crops) when training networks on MNIST, to significantly reduce test error rate for your network. You can use functions from the [torchvision.transforms](http://pytorch.org/docs/master/torchvision/transforms.html) module.

# %%
batch_size = 128
data_path = './data'

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

transform2 = torchvision.transforms.Compose(
    [torchvision.transforms.RandomRotation(30),
     torchvision.transforms.ToTensor(),
     torchvision.transforms.Normalize((0.1307,), (0.3081,))
    ])

# transform3 = torchvision.transforms.Compose(
#     [torchvision.transforms.ColorJitter(),
#      torchvision.transforms.ToTensor(),
#      torchvision.transforms.Normalize((0.1307,), (0.3081,))
#     ])



_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train1 = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train1.train_data = _train1.train_data[:50000]
_train1.train_labels = _train1.train_labels[:50000]

_train2 = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform2)
_train2.train_data = _train2.train_data[:50000]
_train2.train_labels = _train2.train_labels[:50000]

# _train3 = torchvision.datasets.MNIST(
#     data_path, train=True, download=True, transform=transform3)
# _train3.train_data = _train3.train_data[:50000]
# _train3.train_labels = _train3.train_labels[:50000]

_train = torch.utils.data.ConcatDataset([_train1, _train2])

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True,
        pin_memory=True, num_workers=10),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}

class DropoutLayer(Layer):
    def __init__(self, p):
      self.p = p
      
    def forward(self, x):
        factor = 1 / self.p if self.training else 1
        return F.dropout(x, p = self.p, training=self.training) * factor


class  LeakyReLULayer(Layer):
    def forward(self, x):
        return F.leaky_relu(x)
    
    

model = FeedforwardNet(
    [
     AffineLayer(784, 1300),
     DropoutLayer(0.5),
     LeakyReLULayer(),
     AffineLayer(1300, 10),
     SoftMaxLayer()
    ])


with torch.no_grad():
    # Initialize parameters
    for name, p in model.parameters:
        if name == 'W':
            torch.nn.init.xavier_normal_(p)
        elif name == 'b':
            p.zero_()
        else:
            raise ValueError('Unknown parameter name "%s"' % p.name)

SGD(model, mnist_loaders, alpha=0.055, device='cuda')

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# Minibatch    100  | loss  0.53 | err rate 15.62%, steps/s 54.75
# Minibatch    200  | loss  0.32 | err rate 10.94%, steps/s 103.03
# Minibatch    300  | loss  0.23 | err rate  6.25%, steps/s 149.17
# Minibatch    400  | loss  0.24 | err rate  8.59%, steps/s 191.54
# Minibatch    500  | loss  0.24 | err rate  5.47%, steps/s 235.38
# Minibatch    600  | loss  0.20 | err rate  4.69%, steps/s 293.23
# Minibatch    700  | loss  0.26 | err rate  8.59%, steps/s 339.07
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  3.58% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.24 | err rate  6.25%, steps/s 207.34
# Minibatch    900  | loss  0.30 | err rate  6.25%, steps/s 442.79
# Minibatch   1000  | loss  0.11 | err rate  2.34%, steps/s 495.23
# Minibatch   1100  | loss  0.09 | err rate  2.34%, steps/s 515.72
# Minibatch   1200  | loss  0.16 | err rate  4.69%, steps/s 577.38
# Minibatch   1300  | loss  0.15 | err rate  6.25%, steps/s 641.48
# Minibatch   1400  | loss  0.17 | err rate  7.03%, steps/s 660.21
# Minibatch   1500  | loss  0.16 | err rate  6.25%, steps/s 740.40
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  2.56% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.11 | err rate  3.91%, steps/s 419.71
# Minibatch   1700  | loss  0.10 | err rate  3.91%, steps/s 823.53
# Minibatch   1800  | loss  0.16 | err rate  7.03%, steps/s 849.74
# Minibatch   1900  | loss  0.16 | err rate  4.69%, steps/s 938.99
# Minibatch   2000  | loss  0.12 | err rate  3.91%, steps/s 962.32
# Minibatch   2100  | loss  0.14 | err rate  4.69%, steps/s 1009.42
# Minibatch   2200  | loss  0.08 | err rate  3.12%, steps/s 1109.07
# Minibatch   2300  | loss  0.08 | err rate  1.56%, steps/s 1118.49
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  2.50% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.16 | err rate  3.12%, steps/s 626.90
# Minibatch   2500  | loss  0.08 | err rate  2.34%, steps/s 1197.83
# Minibatch   2600  | loss  0.10 | err rate  3.91%, steps/s 1223.93
# Minibatch   2700  | loss  0.19 | err rate  6.25%, steps/s 1329.99
# Minibatch   2800  | loss  0.20 | err rate  7.81%, steps/s 1382.80
# Minibatch   2900  | loss  0.16 | err rate  4.69%, steps/s 1400.16
# Minibatch   3000  | loss  0.11 | err rate  4.69%, steps/s 1473.58
# Minibatch   3100  | loss  0.10 | err rate  3.12%, steps/s 1527.30
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  2.06% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.11 | err rate  3.91%, steps/s 839.03
# Minibatch   3300  | loss  0.11 | err rate  4.69%, steps/s 1619.31
# Minibatch   3400  | loss  0.10 | err rate  3.12%, steps/s 1670.12
# Minibatch   3500  | loss  0.08 | err rate  3.12%, steps/s 1659.58
# Minibatch   3600  | loss  0.12 | err rate  3.12%, steps/s 1740.88
# Minibatch   3700  | loss  0.08 | err rate  3.91%, steps/s 1827.05
# Minibatch   3800  | loss  0.13 | err rate  3.91%, steps/s 1836.16
# Minibatch   3900  | loss  0.10 | err rate  3.12%, steps/s 1951.74
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  2.13% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.14 | err rate  4.69%, steps/s 1014.00
# Minibatch   4100  | loss  0.18 | err rate  6.25%, steps/s 2029.62
# Minibatch   4200  | loss  0.08 | err rate  3.91%, steps/s 2022.29
# Minibatch   4300  | loss  0.05 | err rate  0.78%, steps/s 2113.30
# Minibatch   4400  | loss  0.09 | err rate  0.78%, steps/s 2148.95
# Minibatch   4500  | loss  0.11 | err rate  3.12%, steps/s 2231.28
# Minibatch   4600  | loss  0.08 | err rate  3.12%, steps/s 2232.13
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  1.80% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.04 | err rate  0.78%, steps/s 1252.87
# Minibatch   4800  | loss  0.08 | err rate  3.91%, steps/s 2321.12
# Minibatch   4900  | loss  0.08 | err rate  3.12%, steps/s 2404.01
# Minibatch   5000  | loss  0.13 | err rate  2.34%, steps/s 2454.05
# Minibatch   5100  | loss  0.07 | err rate  1.56%, steps/s 2477.51
# Minibatch   5200  | loss  0.22 | err rate  4.69%, steps/s 2591.21
# Minibatch   5300  | loss  0.05 | err rate  2.34%, steps/s 2553.79
# Minibatch   5400  | loss  0.05 | err rate  1.56%, steps/s 2642.82
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  1.77% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.08 | err rate  2.34%, steps/s 1455.09
# Minibatch   5600  | loss  0.07 | err rate  1.56%, steps/s 2743.73
# Minibatch   5700  | loss  0.05 | err rate  2.34%, steps/s 2756.45
# Minibatch   5800  | loss  0.12 | err rate  4.69%, steps/s 2813.72
# Minibatch   5900  | loss  0.04 | err rate  1.56%, steps/s 2942.44
# Minibatch   6000  | loss  0.06 | err rate  1.56%, steps/s 2980.69
# Minibatch   6100  | loss  0.07 | err rate  1.56%, steps/s 2942.60
# Minibatch   6200  | loss  0.13 | err rate  5.47%, steps/s 3037.52
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  1.73% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.07 | err rate  3.12%, steps/s 1651.75
# Minibatch   6400  | loss  0.10 | err rate  3.91%, steps/s 3173.90
# Minibatch   6500  | loss  0.05 | err rate  1.56%, steps/s 3191.07
# Minibatch   6600  | loss  0.06 | err rate  0.78%, steps/s 3154.70
# Minibatch   6700  | loss  0.04 | err rate  1.56%, steps/s 3294.46
# Minibatch   6800  | loss  0.08 | err rate  3.91%, steps/s 3352.67
# Minibatch   6900  | loss  0.14 | err rate  4.69%, steps/s 3410.63
# Minibatch   7000  | loss  0.10 | err rate  3.91%, steps/s 3566.41
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  1.68% | doing  14 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.08 | err rate  2.34%, steps/s 1900.12
# Minibatch   7200  | loss  0.03 | err rate  0.78%, steps/s 3514.91
# Minibatch   7300  | loss  0.03 | err rate  0.78%, steps/s 3612.94
# Minibatch   7400  | loss  0.05 | err rate  2.34%, steps/s 3600.48
# Minibatch   7500  | loss  0.06 | err rate  1.56%, steps/s 3627.86
# Minibatch   7600  | loss  0.04 | err rate  1.56%, steps/s 3719.59
# Minibatch   7700  | loss  0.05 | err rate  1.56%, steps/s 3735.05
# Minibatch   7800  | loss  0.12 | err rate  2.34%, steps/s 3837.53
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  1.59% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.01 | err rate  0.00%, steps/s 2121.16
# Minibatch   8000  | loss  0.07 | err rate  0.78%, steps/s 3836.85
# Minibatch   8100  | loss  0.02 | err rate  0.00%, steps/s 4020.31
# Minibatch   8200  | loss  0.17 | err rate  3.91%, steps/s 3969.72
# Minibatch   8300  | loss  0.08 | err rate  2.34%, steps/s 4187.10
# Minibatch   8400  | loss  0.06 | err rate  2.34%, steps/s 4049.69
# Minibatch   8500  | loss  0.06 | err rate  3.91%, steps/s 4142.14
# Minibatch   8600  | loss  0.09 | err rate  2.34%, steps/s 4626.81
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  1.54% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.03 | err rate  0.78%, steps/s 2222.95
# Minibatch   8800  | loss  0.13 | err rate  2.34%, steps/s 4340.10
# Minibatch   8900  | loss  0.06 | err rate  2.34%, steps/s 4275.02
# Minibatch   9000  | loss  0.05 | err rate  1.56%, steps/s 4454.86
# Minibatch   9100  | loss  0.05 | err rate  0.78%, steps/s 4453.81
# Minibatch   9200  | loss  0.08 | err rate  3.12%, steps/s 4500.14
# Minibatch   9300  | loss  0.11 | err rate  4.69%, steps/s 4749.30
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  1.56% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.02 | err rate  0.00%, steps/s 2492.47
# Minibatch   9500  | loss  0.03 | err rate  1.56%, steps/s 4485.34
# Minibatch   9600  | loss  0.03 | err rate  1.56%, steps/s 4797.22
# Minibatch   9700  | loss  0.06 | err rate  1.56%, steps/s 4686.37
# Minibatch   9800  | loss  0.08 | err rate  3.91%, steps/s 4875.18
# Minibatch   9900  | loss  0.07 | err rate  3.12%, steps/s 4787.03
# Minibatch  10000  | loss  0.10 | err rate  2.34%, steps/s 5110.10
# Minibatch  10100  | loss  0.04 | err rate  0.78%, steps/s 4819.62
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  1.47% | doing  20 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.06 | err rate  0.78%, steps/s 2713.69
# Minibatch  10300  | loss  0.05 | err rate  2.34%, steps/s 4997.58
# Minibatch  10400  | loss  0.10 | err rate  2.34%, steps/s 4985.03
# Minibatch  10500  | loss  0.05 | err rate  0.78%, steps/s 5210.17
# Minibatch  10600  | loss  0.05 | err rate  0.78%, steps/s 5175.65
# Minibatch  10700  | loss  0.01 | err rate  0.00%, steps/s 5356.94
# Minibatch  10800  | loss  0.06 | err rate  1.56%, steps/s 5228.47
# Minibatch  10900  | loss  0.04 | err rate  1.56%, steps/s 5388.09
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  1.46% | doing  22 epochs
# ----------------------------------------------------------
# Minibatch  11000  | loss  0.04 | err rate  1.56%, steps/s 2903.61
# Minibatch  11100  | loss  0.03 | err rate  0.00%, steps/s 5480.47
# Minibatch  11200  | loss  0.05 | err rate  1.56%, steps/s 5325.12
# Minibatch  11300  | loss  0.02 | err rate  0.00%, steps/s 5479.54
# Minibatch  11400  | loss  0.03 | err rate  0.78%, steps/s 5631.17
# Minibatch  11500  | loss  0.09 | err rate  3.91%, steps/s 5608.91
# Minibatch  11600  | loss  0.02 | err rate  0.00%, steps/s 5804.52
# Minibatch  11700  | loss  0.03 | err rate  0.78%, steps/s 5648.74
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  1.37% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch  11800  | loss  0.04 | err rate  2.34%, steps/s 3079.66
# Minibatch  11900  | loss  0.04 | err rate  0.78%, steps/s 5502.32
# Minibatch  12000  | loss  0.03 | err rate  1.56%, steps/s 5900.95
# Minibatch  12100  | loss  0.02 | err rate  0.00%, steps/s 5906.35
# Minibatch  12200  | loss  0.04 | err rate  1.56%, steps/s 5832.15
# Minibatch  12300  | loss  0.03 | err rate  0.00%, steps/s 5803.81
# Minibatch  12400  | loss  0.08 | err rate  1.56%, steps/s 6161.77
# Minibatch  12500  | loss  0.10 | err rate  2.34%, steps/s 6249.93
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  1.52% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch  12600  | loss  0.03 | err rate  0.78%, steps/s 3339.10
# Minibatch  12700  | loss  0.04 | err rate  1.56%, steps/s 6127.46
# Minibatch  12800  | loss  0.01 | err rate  0.00%, steps/s 6331.92
# Minibatch  12900  | loss  0.04 | err rate  0.78%, steps/s 6000.90
# Minibatch  13000  | loss  0.04 | err rate  1.56%, steps/s 6292.02
# Minibatch  13100  | loss  0.07 | err rate  2.34%, steps/s 7015.67
# Minibatch  13200  | loss  0.03 | err rate  1.56%, steps/s 6288.05
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  1.51% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch  13300  | loss  0.12 | err rate  2.34%, steps/s 3548.49
# Minibatch  13400  | loss  0.05 | err rate  1.56%, steps/s 6567.64
# Minibatch  13500  | loss  0.03 | err rate  0.00%, steps/s 6508.77
# Minibatch  13600  | loss  0.01 | err rate  0.00%, steps/s 6664.88
# Minibatch  13700  | loss  0.06 | err rate  2.34%, steps/s 6728.36
# Minibatch  13800  | loss  0.07 | err rate  2.34%, steps/s 6727.50
# Minibatch  13900  | loss  0.04 | err rate  0.78%, steps/s 6872.77
# Minibatch  14000  | loss  0.05 | err rate  1.56%, steps/s 6889.50
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  1.36% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  14100  | loss  0.07 | err rate  3.12%, steps/s 3745.88
# Minibatch  14200  | loss  0.05 | err rate  0.78%, steps/s 6855.16
# Minibatch  14300  | loss  0.04 | err rate  0.78%, steps/s 7029.65
# Minibatch  14400  | loss  0.03 | err rate  0.00%, steps/s 6843.26
# Minibatch  14500  | loss  0.03 | err rate  0.78%, steps/s 7101.82
# Minibatch  14600  | loss  0.07 | err rate  2.34%, steps/s 6763.08
# Minibatch  14700  | loss  0.03 | err rate  0.78%, steps/s 7269.06
# Minibatch  14800  | loss  0.05 | err rate  0.78%, steps/s 6909.08
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  1.41% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  14900  | loss  0.07 | err rate  3.91%, steps/s 3991.56
# Minibatch  15000  | loss  0.05 | err rate  1.56%, steps/s 6937.89
# Minibatch  15100  | loss  0.06 | err rate  1.56%, steps/s 7405.80
# Minibatch  15200  | loss  0.03 | err rate  1.56%, steps/s 7297.30
# Minibatch  15300  | loss  0.01 | err rate  0.78%, steps/s 7434.95
# Minibatch  15400  | loss  0.07 | err rate  1.56%, steps/s 7852.69
# Minibatch  15500  | loss  0.03 | err rate  0.78%, steps/s 7442.48
# Minibatch  15600  | loss  0.03 | err rate  0.78%, steps/s 7344.07
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  1.47% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  15700  | loss  0.10 | err rate  1.56%, steps/s 4187.29
# Minibatch  15800  | loss  0.06 | err rate  0.78%, steps/s 7514.56
# Minibatch  15900  | loss  0.09 | err rate  3.12%, steps/s 7796.63
# Minibatch  16000  | loss  0.05 | err rate  0.78%, steps/s 7807.48
# Minibatch  16100  | loss  0.04 | err rate  0.78%, steps/s 7749.26
# Minibatch  16200  | loss  0.01 | err rate  0.00%, steps/s 7714.15
# Minibatch  16300  | loss  0.04 | err rate  1.56%, steps/s 7832.31
# Minibatch  16400  | loss  0.04 | err rate  0.78%, steps/s 7979.12
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  1.30% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch  16500  | loss  0.04 | err rate  1.56%, steps/s 4364.70
# Minibatch  16600  | loss  0.02 | err rate  0.78%, steps/s 8014.84
# Minibatch  16700  | loss  0.08 | err rate  0.78%, steps/s 8070.14
# Minibatch  16800  | loss  0.03 | err rate  0.78%, steps/s 8167.69
# Minibatch  16900  | loss  0.02 | err rate  0.78%, steps/s 8487.85
# Minibatch  17000  | loss  0.04 | err rate  0.78%, steps/s 8308.46
# Minibatch  17100  | loss  0.07 | err rate  1.56%, steps/s 8389.97
# Minibatch  17200  | loss  0.05 | err rate  1.56%, steps/s 8852.28
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  1.32% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch  17300  | loss  0.02 | err rate  0.00%, steps/s 4335.58
# Minibatch  17400  | loss  0.01 | err rate  0.00%, steps/s 8443.80
# Minibatch  17500  | loss  0.04 | err rate  1.56%, steps/s 8095.27
# Minibatch  17600  | loss  0.04 | err rate  0.78%, steps/s 8739.10
# Minibatch  17700  | loss  0.04 | err rate  1.56%, steps/s 8519.49
# Minibatch  17800  | loss  0.05 | err rate  0.78%, steps/s 8422.42
# Minibatch  17900  | loss  0.03 | err rate  0.78%, steps/s 8850.19
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  1.43% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch  18000  | loss  0.06 | err rate  2.34%, steps/s 4784.11
# Minibatch  18100  | loss  0.06 | err rate  2.34%, steps/s 8742.83
# Minibatch  18200  | loss  0.07 | err rate  3.12%, steps/s 8939.64
# Minibatch  18300  | loss  0.03 | err rate  0.78%, steps/s 8793.54
# Minibatch  18400  | loss  0.05 | err rate  0.78%, steps/s 8944.15
# Minibatch  18500  | loss  0.07 | err rate  2.34%, steps/s 9025.58
# Minibatch  18600  | loss  0.06 | err rate  2.34%, steps/s 8972.25
# Minibatch  18700  | loss  0.05 | err rate  2.34%, steps/s 9211.63
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  1.38% | doing  32 epochs
# ----------------------------------------------------------
# Minibatch  18800  | loss  0.04 | err rate  2.34%, steps/s 4984.62
# Minibatch  18900  | loss  0.03 | err rate  0.78%, steps/s 9405.07
# Minibatch  19000  | loss  0.03 | err rate  0.78%, steps/s 9100.21
# Minibatch  19100  | loss  0.07 | err rate  1.56%, steps/s 9423.97
# Minibatch  19200  | loss  0.02 | err rate  0.78%, steps/s 9444.57
# Minibatch  19300  | loss  0.03 | err rate  1.56%, steps/s 9265.76
# Minibatch  19400  | loss  0.03 | err rate  0.78%, steps/s 9374.33
# Minibatch  19500  | loss  0.05 | err rate  1.56%, steps/s 9450.54
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  1.23% | doing  38 epochs
# ----------------------------------------------------------
# Minibatch  19600  | loss  0.02 | err rate  0.78%, steps/s 5230.70
# Minibatch  19700  | loss  0.04 | err rate  0.78%, steps/s 9423.03
# Minibatch  19800  | loss  0.07 | err rate  1.56%, steps/s 9853.25
# Minibatch  19900  | loss  0.04 | err rate  2.34%, steps/s 9696.24
# Minibatch  20000  | loss  0.06 | err rate  2.34%, steps/s 9904.19
# Minibatch  20100  | loss  0.09 | err rate  3.12%, steps/s 9676.78
# Minibatch  20200  | loss  0.05 | err rate  2.34%, steps/s 9939.26
# Minibatch  20300  | loss  0.02 | err rate  0.00%, steps/s 9813.69
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  1.31% | doing  38 epochs
# ----------------------------------------------------------
# Minibatch  20400  | loss  0.04 | err rate  0.78%, steps/s 5549.22
# Minibatch  20500  | loss  0.06 | err rate  1.56%, steps/s 9469.53
# Minibatch  20600  | loss  0.03 | err rate  0.78%, steps/s 10062.34
# Minibatch  20700  | loss  0.02 | err rate  0.78%, steps/s 10022.22
# Minibatch  20800  | loss  0.05 | err rate  1.56%, steps/s 9904.65
# Minibatch  20900  | loss  0.06 | err rate  1.56%, steps/s 10255.73
# Minibatch  21000  | loss  0.01 | err rate  0.00%, steps/s 10293.60
# Minibatch  21100  | loss  0.02 | err rate  0.78%, steps/s 10006.06
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  1.20% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  21200  | loss  0.08 | err rate  3.12%, steps/s 5597.47
# Minibatch  21300  | loss  0.01 | err rate  0.78%, steps/s 10111.58
# Minibatch  21400  | loss  0.02 | err rate  0.00%, steps/s 10959.85
# Minibatch  21500  | loss  0.06 | err rate  2.34%, steps/s 10049.37
# Minibatch  21600  | loss  0.06 | err rate  3.12%, steps/s 10821.81
# Minibatch  21700  | loss  0.02 | err rate  0.00%, steps/s 10700.22
# Minibatch  21800  | loss  0.03 | err rate  0.78%, steps/s 10709.98
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  1.28% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  21900  | loss  0.03 | err rate  0.78%, steps/s 5911.69
# Minibatch  22000  | loss  0.06 | err rate  2.34%, steps/s 10649.21
# Minibatch  22100  | loss  0.03 | err rate  0.78%, steps/s 10858.89
# Minibatch  22200  | loss  0.04 | err rate  1.56%, steps/s 10258.84
# Minibatch  22300  | loss  0.04 | err rate  0.78%, steps/s 10935.34
# Minibatch  22400  | loss  0.01 | err rate  0.00%, steps/s 10917.29
# Minibatch  22500  | loss  0.05 | err rate  0.78%, steps/s 10739.75
# Minibatch  22600  | loss  0.03 | err rate  0.78%, steps/s 10987.67
# ----------------------------------------------------------
# After epoch 29 | valid err rate:  1.24% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  22700  | loss  0.01 | err rate  0.00%, steps/s 5958.71
# Minibatch  22800  | loss  0.01 | err rate  0.00%, steps/s 11606.00
# Minibatch  22900  | loss  0.05 | err rate  2.34%, steps/s 11071.56
# Minibatch  23000  | loss  0.07 | err rate  1.56%, steps/s 11436.35
# Minibatch  23100  | loss  0.04 | err rate  1.56%, steps/s 11770.91
# Minibatch  23200  | loss  0.02 | err rate  0.78%, steps/s 11250.43
# Minibatch  23300  | loss  0.02 | err rate  0.78%, steps/s 11439.84
# Minibatch  23400  | loss  0.03 | err rate  1.56%, steps/s 11559.87
# ----------------------------------------------------------
# After epoch 30 | valid err rate:  1.26% | doing  41 epochs
# ----------------------------------------------------------
# Minibatch  23500  | loss  0.03 | err rate  1.56%, steps/s 6139.81
# Minibatch  23600  | loss  0.02 | err rate  0.78%, steps/s 11451.22
# Minibatch  23700  | loss  0.06 | err rate  1.56%, steps/s 11928.47
# Minibatch  23800  | loss  0.10 | err rate  2.34%, steps/s 11884.34
# Minibatch  23900  | loss  0.05 | err rate  1.56%, steps/s 11266.28
# Minibatch  24000  | loss  0.01 | err rate  0.00%, steps/s 11931.01
# Minibatch  24100  | loss  0.04 | err rate  0.78%, steps/s 12102.83
# Minibatch  24200  | loss  0.01 | err rate  0.00%, steps/s 11761.84
# ----------------------------------------------------------
# After epoch 31 | valid err rate:  1.19% | doing  47 epochs
# ----------------------------------------------------------
# Minibatch  24300  | loss  0.01 | err rate  0.00%, steps/s 6455.16
# Minibatch  24400  | loss  0.03 | err rate  0.78%, steps/s 11650.44
# Minibatch  24500  | loss  0.05 | err rate  1.56%, steps/s 11927.26
# Minibatch  24600  | loss  0.02 | err rate  0.00%, steps/s 11940.71
# Minibatch  24700  | loss  0.03 | err rate  0.78%, steps/s 12239.04
# Minibatch  24800  | loss  0.06 | err rate  1.56%, steps/s 12048.15
# Minibatch  24900  | loss  0.02 | err rate  0.78%, steps/s 11718.99
# Minibatch  25000  | loss  0.06 | err rate  1.56%, steps/s 12665.60
# ----------------------------------------------------------
# After epoch 32 | valid err rate:  1.24% | doing  47 epochs
# ----------------------------------------------------------
# Minibatch  25100  | loss  0.01 | err rate  0.00%, steps/s 6531.37
# Minibatch  25200  | loss  0.09 | err rate  2.34%, steps/s 12377.42
# Minibatch  25300  | loss  0.03 | err rate  0.78%, steps/s 11961.02
# Minibatch  25400  | loss  0.09 | err rate  3.91%, steps/s 12875.78
# Minibatch  25500  | loss  0.04 | err rate  1.56%, steps/s 12405.59
# Minibatch  25600  | loss  0.03 | err rate  1.56%, steps/s 12574.52
# Minibatch  25700  | loss  0.02 | err rate  0.78%, steps/s 12550.87
# Minibatch  25800  | loss  0.02 | err rate  0.78%, steps/s 12987.13
# ----------------------------------------------------------
# After epoch 33 | valid err rate:  1.20% | doing  47 epochs
# ----------------------------------------------------------
# Minibatch  25900  | loss  0.06 | err rate  1.56%, steps/s 6522.34
# Minibatch  26000  | loss  0.03 | err rate  1.56%, steps/s 12794.93
# Minibatch  26100  | loss  0.04 | err rate  1.56%, steps/s 12415.27
# Minibatch  26200  | loss  0.02 | err rate  0.00%, steps/s 12396.85
# Minibatch  26300  | loss  0.06 | err rate  1.56%, steps/s 12641.70
# Minibatch  26400  | loss  0.02 | err rate  0.78%, steps/s 13373.11
# Minibatch  26500  | loss  0.04 | err rate  0.78%, steps/s 12831.89
# ----------------------------------------------------------
# After epoch 34 | valid err rate:  1.20% | doing  47 epochs
# ----------------------------------------------------------
# Minibatch  26600  | loss  0.05 | err rate  1.56%, steps/s 7044.05
# Minibatch  26700  | loss  0.06 | err rate  0.78%, steps/s 12760.20
# Minibatch  26800  | loss  0.06 | err rate  3.91%, steps/s 12904.04
# Minibatch  26900  | loss  0.02 | err rate  0.00%, steps/s 13165.96
# Minibatch  27000  | loss  0.02 | err rate  0.78%, steps/s 13080.06
# Minibatch  27100  | loss  0.09 | err rate  2.34%, steps/s 13559.01
# Minibatch  27200  | loss  0.01 | err rate  0.00%, steps/s 13391.13
# Minibatch  27300  | loss  0.03 | err rate  1.56%, steps/s 13223.40
# ----------------------------------------------------------
# After epoch 35 | valid err rate:  1.16% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  27400  | loss  0.04 | err rate  0.78%, steps/s 7343.85
# Minibatch  27500  | loss  0.02 | err rate  0.78%, steps/s 13557.83
# Minibatch  27600  | loss  0.04 | err rate  1.56%, steps/s 12835.47
# Minibatch  27700  | loss  0.01 | err rate  0.00%, steps/s 13751.67
# Minibatch  27800  | loss  0.04 | err rate  0.78%, steps/s 13615.83
# Minibatch  27900  | loss  0.01 | err rate  0.00%, steps/s 13427.71
# Minibatch  28000  | loss  0.02 | err rate  0.00%, steps/s 13556.35
# Minibatch  28100  | loss  0.01 | err rate  0.00%, steps/s 13665.40
# ----------------------------------------------------------
# After epoch 36 | valid err rate:  1.17% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  28200  | loss  0.03 | err rate  0.78%, steps/s 7656.16
# Minibatch  28300  | loss  0.04 | err rate  1.56%, steps/s 13751.21
# Minibatch  28400  | loss  0.01 | err rate  0.78%, steps/s 13616.19
# Minibatch  28500  | loss  0.01 | err rate  0.78%, steps/s 13531.23
# Minibatch  28600  | loss  0.01 | err rate  0.78%, steps/s 13662.49
# Minibatch  28700  | loss  0.01 | err rate  0.00%, steps/s 13662.79
# Minibatch  28800  | loss  0.04 | err rate  0.78%, steps/s 14128.44
# Minibatch  28900  | loss  0.02 | err rate  0.78%, steps/s 14294.40
# ----------------------------------------------------------
# After epoch 37 | valid err rate:  1.19% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  29000  | loss  0.06 | err rate  2.34%, steps/s 7823.02
# Minibatch  29100  | loss  0.01 | err rate  0.00%, steps/s 13730.64
# Minibatch  29200  | loss  0.05 | err rate  1.56%, steps/s 13951.41
# Minibatch  29300  | loss  0.02 | err rate  0.00%, steps/s 14304.40
# Minibatch  29400  | loss  0.02 | err rate  0.78%, steps/s 14174.92
# Minibatch  29500  | loss  0.03 | err rate  0.78%, steps/s 14726.16
# Minibatch  29600  | loss  0.02 | err rate  0.78%, steps/s 14431.06
# Minibatch  29700  | loss  0.02 | err rate  0.78%, steps/s 14836.79
# ----------------------------------------------------------
# After epoch 38 | valid err rate:  1.28% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  29800  | loss  0.04 | err rate  1.56%, steps/s 7781.73
# Minibatch  29900  | loss  0.03 | err rate  1.56%, steps/s 14660.49
# Minibatch  30000  | loss  0.03 | err rate  0.78%, steps/s 14704.72
# Minibatch  30100  | loss  0.04 | err rate  1.56%, steps/s 14725.26
# Minibatch  30200  | loss  0.05 | err rate  2.34%, steps/s 14984.96
# Minibatch  30300  | loss  0.01 | err rate  0.00%, steps/s 14341.75
# Minibatch  30400  | loss  0.03 | err rate  0.00%, steps/s 15000.71
# ----------------------------------------------------------
# After epoch 39 | valid err rate:  1.20% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  30500  | loss  0.01 | err rate  0.00%, steps/s 8200.93
# Minibatch  30600  | loss  0.03 | err rate  0.78%, steps/s 14861.05
# Minibatch  30700  | loss  0.08 | err rate  3.12%, steps/s 14629.02
# Minibatch  30800  | loss  0.04 | err rate  1.56%, steps/s 15087.55
# Minibatch  30900  | loss  0.01 | err rate  0.00%, steps/s 15512.81
# Minibatch  31000  | loss  0.06 | err rate  2.34%, steps/s 15040.03
# Minibatch  31100  | loss  0.05 | err rate  2.34%, steps/s 14851.93
# Minibatch  31200  | loss  0.02 | err rate  0.78%, steps/s 14480.98
# ----------------------------------------------------------
# After epoch 40 | valid err rate:  1.18% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  31300  | loss  0.03 | err rate  0.78%, steps/s 7839.42
# Minibatch  31400  | loss  0.03 | err rate  2.34%, steps/s 15121.83
# Minibatch  31500  | loss  0.02 | err rate  0.78%, steps/s 15178.48
# Minibatch  31600  | loss  0.01 | err rate  0.00%, steps/s 15045.31
# Minibatch  31700  | loss  0.02 | err rate  0.00%, steps/s 14490.57
# Minibatch  31800  | loss  0.01 | err rate  0.00%, steps/s 15506.36
# Minibatch  31900  | loss  0.03 | err rate  1.56%, steps/s 14473.43
# Minibatch  32000  | loss  0.02 | err rate  0.00%, steps/s 14680.79
# ----------------------------------------------------------
# After epoch 41 | valid err rate:  1.16% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  32100  | loss  0.04 | err rate  1.56%, steps/s 6971.59
# Minibatch  32200  | loss  0.01 | err rate  0.78%, steps/s 14590.50
# Minibatch  32300  | loss  0.01 | err rate  0.00%, steps/s 14429.11
# Minibatch  32400  | loss  0.04 | err rate  2.34%, steps/s 16290.09
# Minibatch  32500  | loss  0.02 | err rate  0.78%, steps/s 16216.65
# Minibatch  32600  | loss  0.01 | err rate  0.00%, steps/s 15968.19
# Minibatch  32700  | loss  0.06 | err rate  0.78%, steps/s 16100.17
# Minibatch  32800  | loss  0.01 | err rate  0.00%, steps/s 16000.58
# ----------------------------------------------------------
# After epoch 42 | valid err rate:  1.20% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  32900  | loss  0.04 | err rate  1.56%, steps/s 8586.89
# Minibatch  33000  | loss  0.02 | err rate  0.78%, steps/s 16054.22
# Minibatch  33100  | loss  0.07 | err rate  0.78%, steps/s 16284.65
# Minibatch  33200  | loss  0.05 | err rate  1.56%, steps/s 17004.82
# Minibatch  33300  | loss  0.03 | err rate  1.56%, steps/s 16354.72
# Minibatch  33400  | loss  0.05 | err rate  1.56%, steps/s 16332.97
# Minibatch  33500  | loss  0.02 | err rate  0.78%, steps/s 15972.96
# Minibatch  33600  | loss  0.02 | err rate  0.00%, steps/s 17011.53
# ----------------------------------------------------------
# After epoch 43 | valid err rate:  1.23% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  33700  | loss  0.05 | err rate  2.34%, steps/s 8984.92
# Minibatch  33800  | loss  0.02 | err rate  0.00%, steps/s 16092.40
# Minibatch  33900  | loss  0.05 | err rate  0.78%, steps/s 16572.25
# Minibatch  34000  | loss  0.04 | err rate  0.78%, steps/s 16429.81
# Minibatch  34100  | loss  0.04 | err rate  0.78%, steps/s 17002.65
# Minibatch  34200  | loss  0.02 | err rate  0.00%, steps/s 16900.45
# Minibatch  34300  | loss  0.01 | err rate  0.00%, steps/s 16780.43
# Minibatch  34400  | loss  0.05 | err rate  1.56%, steps/s 17442.74
# ----------------------------------------------------------
# After epoch 44 | valid err rate:  1.19% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  34500  | loss  0.02 | err rate  1.56%, steps/s 9101.99
# Minibatch  34600  | loss  0.03 | err rate  1.56%, steps/s 16519.71
# Minibatch  34700  | loss  0.05 | err rate  1.56%, steps/s 17141.54
# Minibatch  34800  | loss  0.01 | err rate  0.00%, steps/s 17313.75
# Minibatch  34900  | loss  0.05 | err rate  0.78%, steps/s 17292.28
# Minibatch  35000  | loss  0.02 | err rate  0.00%, steps/s 17306.95
# Minibatch  35100  | loss  0.01 | err rate  0.00%, steps/s 17467.16
# ----------------------------------------------------------
# After epoch 45 | valid err rate:  1.22% | doing  53 epochs
# ----------------------------------------------------------
# Minibatch  35200  | loss  0.02 | err rate  0.00%, steps/s 9403.73
# Minibatch  35300  | loss  0.02 | err rate  0.78%, steps/s 17520.31
# Minibatch  35400  | loss  0.03 | err rate  1.56%, steps/s 17282.26
# Minibatch  35500  | loss  0.03 | err rate  0.78%, steps/s 17041.92
# Minibatch  35600  | loss  0.01 | err rate  0.00%, steps/s 17642.32
# Minibatch  35700  | loss  0.04 | err rate  0.78%, steps/s 17342.65
# Minibatch  35800  | loss  0.05 | err rate  0.78%, steps/s 17570.60
# Minibatch  35900  | loss  0.04 | err rate  2.34%, steps/s 17663.28
# ----------------------------------------------------------
# After epoch 46 | valid err rate:  1.09% | doing  70 epochs
# ----------------------------------------------------------
# Minibatch  36000  | loss  0.04 | err rate  1.56%, steps/s 9511.38
# Minibatch  36100  | loss  0.02 | err rate  0.00%, steps/s 17138.40
# Minibatch  36200  | loss  0.02 | err rate  0.78%, steps/s 17014.50
# Minibatch  36300  | loss  0.08 | err rate  2.34%, steps/s 17766.58
# Minibatch  36400  | loss  0.04 | err rate  1.56%, steps/s 17839.81
# Minibatch  36500  | loss  0.03 | err rate  0.78%, steps/s 17606.31
# Minibatch  36600  | loss  0.01 | err rate  0.00%, steps/s 17868.81
# Minibatch  36700  | loss  0.01 | err rate  0.00%, steps/s 17291.56
# ----------------------------------------------------------
# After epoch 47 | valid err rate:  1.15% | doing  70 epochs
# ----------------------------------------------------------
# Minibatch  36800  | loss  0.04 | err rate  2.34%, steps/s 9630.92
# Minibatch  36900  | loss  0.02 | err rate  0.78%, steps/s 17682.51
# Minibatch  37000  | loss  0.04 | err rate  1.56%, steps/s 18244.28
# Minibatch  37100  | loss  0.01 | err rate  0.00%, steps/s 17937.90
# Minibatch  37200  | loss  0.01 | err rate  0.00%, steps/s 18467.33
# Minibatch  37300  | loss  0.03 | err rate  0.78%, steps/s 17909.57
# Minibatch  37400  | loss  0.03 | err rate  0.78%, steps/s 17964.02
# Minibatch  37500  | loss  0.03 | err rate  0.78%, steps/s 18369.74
# ----------------------------------------------------------
# After epoch 48 | valid err rate:  1.14% | doing  70 epochs
# ----------------------------------------------------------
# Minibatch  37600  | loss  0.02 | err rate  0.00%, steps/s 10274.99
# Minibatch  37700  | loss  0.09 | err rate  3.12%, steps/s 17853.08
# Minibatch  37800  | loss  0.02 | err rate  0.78%, steps/s 18716.15
# Minibatch  37900  | loss  0.04 | err rate  1.56%, steps/s 18651.01
# Minibatch  38000  | loss  0.05 | err rate  0.78%, steps/s 18480.04
# Minibatch  38100  | loss  0.07 | err rate  2.34%, steps/s 18572.57
# Minibatch  38200  | loss  0.03 | err rate  0.78%, steps/s 19086.73
# Minibatch  38300  | loss  0.03 | err rate  0.78%, steps/s 17910.39
# ----------------------------------------------------------
# After epoch 49 | valid err rate:  1.14% | doing  70 epochs
# ----------------------------------------------------------
# Minibatch  38400  | loss  0.01 | err rate  0.00%, steps/s 10251.85
# Minibatch  38500  | loss  0.02 | err rate  0.00%, steps/s 18622.61
# Minibatch  38600  | loss  0.02 | err rate  0.00%, steps/s 19058.49
# Minibatch  38700  | loss  0.05 | err rate  1.56%, steps/s 18303.54
# Minibatch  38800  | loss  0.03 | err rate  0.78%, steps/s 19223.98
# Minibatch  38900  | loss  0.02 | err rate  0.00%, steps/s 18831.69
# Minibatch  39000  | loss  0.01 | err rate  0.00%, steps/s 18635.41
# Minibatch  39100  | loss  0.05 | err rate  3.12%, steps/s 21621.03
# ----------------------------------------------------------
# After epoch 50 | valid err rate:  1.10% | doing  70 epochs
# ----------------------------------------------------------
# Minibatch  39200  | loss  0.03 | err rate  0.78%, steps/s 9739.11
# Minibatch  39300  | loss  0.04 | err rate  0.78%, steps/s 19575.87
# Minibatch  39400  | loss  0.01 | err rate  0.00%, steps/s 18981.32
# Minibatch  39500  | loss  0.05 | err rate  1.56%, steps/s 19592.93
# Minibatch  39600  | loss  0.06 | err rate  1.56%, steps/s 18855.22
# Minibatch  39700  | loss  0.04 | err rate  1.56%, steps/s 19689.15
# Minibatch  39800  | loss  0.02 | err rate  0.78%, steps/s 18986.91
# ----------------------------------------------------------
# After epoch 51 | valid err rate:  1.15% | doing  70 epochs
# ----------------------------------------------------------
# Minibatch  39900  | loss  0.05 | err rate  2.34%, steps/s 10588.80
# Minibatch  40000  | loss  0.06 | err rate  2.34%, steps/s 19176.91
# Minibatch  40100  | loss  0.04 | err rate  1.56%, steps/s 19503.84
# Minibatch  40200  | loss  0.01 | err rate  0.00%, steps/s 19793.08
# Minibatch  40300  | loss  0.03 | err rate  0.78%, steps/s 20084.87
# Minibatch  40400  | loss  0.09 | err rate  1.56%, steps/s 19528.67
# Minibatch  40500  | loss  0.01 | err rate  0.00%, steps/s 20492.34
# Minibatch  40600  | loss  0.02 | err rate  0.00%, steps/s 20699.87
# ----------------------------------------------------------
# After epoch 52 | valid err rate:  1.07% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  40700  | loss  0.02 | err rate  0.00%, steps/s 10767.10
# Minibatch  40800  | loss  0.02 | err rate  0.00%, steps/s 19559.32
# Minibatch  40900  | loss  0.01 | err rate  0.00%, steps/s 19980.29
# Minibatch  41000  | loss  0.02 | err rate  0.78%, steps/s 19830.51
# Minibatch  41100  | loss  0.02 | err rate  0.00%, steps/s 20658.69
# Minibatch  41200  | loss  0.01 | err rate  0.00%, steps/s 21015.74
# Minibatch  41300  | loss  0.02 | err rate  0.78%, steps/s 20382.17
# Minibatch  41400  | loss  0.04 | err rate  0.78%, steps/s 20361.91
# ----------------------------------------------------------
# After epoch 53 | valid err rate:  1.11% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  41500  | loss  0.04 | err rate  0.78%, steps/s 11110.40
# Minibatch  41600  | loss  0.01 | err rate  0.00%, steps/s 20156.78
# Minibatch  41700  | loss  0.05 | err rate  1.56%, steps/s 20278.25
# Minibatch  41800  | loss  0.06 | err rate  0.78%, steps/s 20039.71
# Minibatch  41900  | loss  0.02 | err rate  0.78%, steps/s 20244.12
# Minibatch  42000  | loss  0.01 | err rate  0.00%, steps/s 20869.07
# Minibatch  42100  | loss  0.01 | err rate  0.00%, steps/s 20593.37
# Minibatch  42200  | loss  0.02 | err rate  0.78%, steps/s 20259.53
# ----------------------------------------------------------
# After epoch 54 | valid err rate:  1.10% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  42300  | loss  0.06 | err rate  0.78%, steps/s 11236.36
# Minibatch  42400  | loss  0.03 | err rate  1.56%, steps/s 19991.72
# Minibatch  42500  | loss  0.02 | err rate  0.78%, steps/s 21186.27
# Minibatch  42600  | loss  0.04 | err rate  0.78%, steps/s 20512.22
# Minibatch  42700  | loss  0.01 | err rate  0.00%, steps/s 21154.02
# Minibatch  42800  | loss  0.02 | err rate  0.00%, steps/s 20752.73
# Minibatch  42900  | loss  0.04 | err rate  0.78%, steps/s 22079.31
# Minibatch  43000  | loss  0.04 | err rate  1.56%, steps/s 21785.07
# ----------------------------------------------------------
# After epoch 55 | valid err rate:  1.08% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  43100  | loss  0.09 | err rate  1.56%, steps/s 11326.74
# Minibatch  43200  | loss  0.02 | err rate  0.78%, steps/s 21130.71
# Minibatch  43300  | loss  0.01 | err rate  0.00%, steps/s 20545.48
# Minibatch  43400  | loss  0.01 | err rate  0.00%, steps/s 20850.80
# Minibatch  43500  | loss  0.06 | err rate  2.34%, steps/s 21362.03
# Minibatch  43600  | loss  0.06 | err rate  3.12%, steps/s 20712.01
# Minibatch  43700  | loss  0.02 | err rate  0.78%, steps/s 21414.90
# ----------------------------------------------------------
# After epoch 56 | valid err rate:  1.10% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  43800  | loss  0.02 | err rate  0.78%, steps/s 11844.78
# Minibatch  43900  | loss  0.05 | err rate  1.56%, steps/s 21047.06
# Minibatch  44000  | loss  0.04 | err rate  0.78%, steps/s 21279.36
# Minibatch  44100  | loss  0.05 | err rate  1.56%, steps/s 22213.67
# Minibatch  44200  | loss  0.02 | err rate  0.00%, steps/s 21042.46
# Minibatch  44300  | loss  0.04 | err rate  0.78%, steps/s 21510.12
# Minibatch  44400  | loss  0.01 | err rate  0.00%, steps/s 21823.49
# Minibatch  44500  | loss  0.01 | err rate  0.00%, steps/s 21897.05
# ----------------------------------------------------------
# After epoch 57 | valid err rate:  1.09% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  44600  | loss  0.02 | err rate  0.78%, steps/s 11846.68
# Minibatch  44700  | loss  0.01 | err rate  0.00%, steps/s 22204.55
# Minibatch  44800  | loss  0.03 | err rate  0.78%, steps/s 21367.09
# Minibatch  44900  | loss  0.03 | err rate  0.78%, steps/s 21664.47
# Minibatch  45000  | loss  0.03 | err rate  1.56%, steps/s 22003.59
# Minibatch  45100  | loss  0.07 | err rate  0.78%, steps/s 21975.59
# Minibatch  45200  | loss  0.01 | err rate  0.00%, steps/s 21585.13
# Minibatch  45300  | loss  0.02 | err rate  0.78%, steps/s 23168.08
# ----------------------------------------------------------
# After epoch 58 | valid err rate:  1.07% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  45400  | loss  0.03 | err rate  0.78%, steps/s 12187.76
# Minibatch  45500  | loss  0.01 | err rate  0.00%, steps/s 21482.25
# Minibatch  45600  | loss  0.07 | err rate  2.34%, steps/s 22092.90
# Minibatch  45700  | loss  0.02 | err rate  1.56%, steps/s 22268.30
# Minibatch  45800  | loss  0.02 | err rate  0.00%, steps/s 22136.66
# Minibatch  45900  | loss  0.01 | err rate  0.00%, steps/s 22742.30
# Minibatch  46000  | loss  0.02 | err rate  0.00%, steps/s 23014.55
# Minibatch  46100  | loss  0.03 | err rate  0.78%, steps/s 23194.55
# ----------------------------------------------------------
# After epoch 59 | valid err rate:  1.09% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  46200  | loss  0.05 | err rate  2.34%, steps/s 12008.58
# Minibatch  46300  | loss  0.03 | err rate  0.78%, steps/s 22962.35
# Minibatch  46400  | loss  0.03 | err rate  0.78%, steps/s 22467.79
# Minibatch  46500  | loss  0.01 | err rate  0.00%, steps/s 22616.04
# Minibatch  46600  | loss  0.01 | err rate  0.00%, steps/s 23030.11
# Minibatch  46700  | loss  0.02 | err rate  0.00%, steps/s 23766.53
# Minibatch  46800  | loss  0.03 | err rate  0.78%, steps/s 23174.55
# Minibatch  46900  | loss  0.01 | err rate  0.00%, steps/s 22331.69
# ----------------------------------------------------------
# After epoch 60 | valid err rate:  1.13% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  47000  | loss  0.02 | err rate  0.00%, steps/s 12602.41
# Minibatch  47100  | loss  0.07 | err rate  2.34%, steps/s 23368.81
# Minibatch  47200  | loss  0.03 | err rate  0.78%, steps/s 23141.51
# Minibatch  47300  | loss  0.01 | err rate  0.00%, steps/s 22743.97
# Minibatch  47400  | loss  0.03 | err rate  0.78%, steps/s 23107.23
# Minibatch  47500  | loss  0.01 | err rate  0.00%, steps/s 23277.47
# Minibatch  47600  | loss  0.07 | err rate  1.56%, steps/s 23108.56
# Minibatch  47700  | loss  0.03 | err rate  0.78%, steps/s 25564.61
# ----------------------------------------------------------
# After epoch 61 | valid err rate:  1.07% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  47800  | loss  0.01 | err rate  0.00%, steps/s 12106.59
# Minibatch  47900  | loss  0.01 | err rate  0.00%, steps/s 23763.49
# Minibatch  48000  | loss  0.02 | err rate  0.78%, steps/s 23666.68
# Minibatch  48100  | loss  0.03 | err rate  0.78%, steps/s 23655.54
# Minibatch  48200  | loss  0.01 | err rate  0.00%, steps/s 23057.85
# Minibatch  48300  | loss  0.02 | err rate  0.00%, steps/s 23633.98
# Minibatch  48400  | loss  0.02 | err rate  0.00%, steps/s 24580.99
# ----------------------------------------------------------
# After epoch 62 | valid err rate:  1.11% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  48500  | loss  0.01 | err rate  0.78%, steps/s 12867.52
# Minibatch  48600  | loss  0.04 | err rate  0.78%, steps/s 24542.93
# Minibatch  48700  | loss  0.01 | err rate  0.00%, steps/s 23785.15
# Minibatch  48800  | loss  0.01 | err rate  0.00%, steps/s 23471.50
# Minibatch  48900  | loss  0.04 | err rate  0.78%, steps/s 23694.51
# Minibatch  49000  | loss  0.03 | err rate  0.78%, steps/s 23441.27
# Minibatch  49100  | loss  0.02 | err rate  0.78%, steps/s 24409.43
# Minibatch  49200  | loss  0.00 | err rate  0.00%, steps/s 23675.92
# ----------------------------------------------------------
# After epoch 63 | valid err rate:  1.11% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  49300  | loss  0.09 | err rate  3.12%, steps/s 13080.72
# Minibatch  49400  | loss  0.01 | err rate  0.00%, steps/s 23021.18
# Minibatch  49500  | loss  0.02 | err rate  0.00%, steps/s 24877.26
# Minibatch  49600  | loss  0.01 | err rate  0.00%, steps/s 24170.91
# Minibatch  49700  | loss  0.01 | err rate  0.00%, steps/s 24248.96
# Minibatch  49800  | loss  0.03 | err rate  0.78%, steps/s 24357.41
# Minibatch  49900  | loss  0.01 | err rate  0.78%, steps/s 24287.68
# Minibatch  50000  | loss  0.02 | err rate  0.78%, steps/s 24935.93
# ----------------------------------------------------------
# After epoch 64 | valid err rate:  1.13% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  50100  | loss  0.01 | err rate  0.00%, steps/s 13455.76
# Minibatch  50200  | loss  0.01 | err rate  0.00%, steps/s 23679.29
# Minibatch  50300  | loss  0.04 | err rate  0.78%, steps/s 24523.93
# Minibatch  50400  | loss  0.05 | err rate  1.56%, steps/s 24141.78
# Minibatch  50500  | loss  0.02 | err rate  0.78%, steps/s 23819.05
# Minibatch  50600  | loss  0.02 | err rate  0.78%, steps/s 25654.08
# Minibatch  50700  | loss  0.04 | err rate  0.78%, steps/s 24664.09
# Minibatch  50800  | loss  0.03 | err rate  0.78%, steps/s 24848.79
# ----------------------------------------------------------
# After epoch 65 | valid err rate:  1.08% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  50900  | loss  0.01 | err rate  0.00%, steps/s 13507.11
# Minibatch  51000  | loss  0.05 | err rate  0.78%, steps/s 24427.05
# Minibatch  51100  | loss  0.02 | err rate  0.78%, steps/s 25149.08
# Minibatch  51200  | loss  0.04 | err rate  0.78%, steps/s 25104.93
# Minibatch  51300  | loss  0.04 | err rate  1.56%, steps/s 25107.94
# Minibatch  51400  | loss  0.03 | err rate  0.78%, steps/s 24743.69
# Minibatch  51500  | loss  0.02 | err rate  1.56%, steps/s 25382.24
# Minibatch  51600  | loss  0.03 | err rate  1.56%, steps/s 26028.73
# ----------------------------------------------------------
# After epoch 66 | valid err rate:  1.14% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  51700  | loss  0.01 | err rate  0.00%, steps/s 13652.08
# Minibatch  51800  | loss  0.01 | err rate  0.00%, steps/s 24737.76
# Minibatch  51900  | loss  0.02 | err rate  0.78%, steps/s 25229.42
# Minibatch  52000  | loss  0.01 | err rate  0.00%, steps/s 25031.24
# Minibatch  52100  | loss  0.01 | err rate  0.00%, steps/s 26046.38
# Minibatch  52200  | loss  0.01 | err rate  0.00%, steps/s 24741.05
# Minibatch  52300  | loss  0.02 | err rate  0.00%, steps/s 25844.68
# ----------------------------------------------------------
# After epoch 67 | valid err rate:  1.12% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  52400  | loss  0.01 | err rate  0.00%, steps/s 14091.56
# Minibatch  52500  | loss  0.02 | err rate  1.56%, steps/s 24927.26
# Minibatch  52600  | loss  0.03 | err rate  0.78%, steps/s 25236.30
# Minibatch  52700  | loss  0.01 | err rate  0.78%, steps/s 25360.23
# Minibatch  52800  | loss  0.05 | err rate  1.56%, steps/s 26621.30
# Minibatch  52900  | loss  0.01 | err rate  0.00%, steps/s 25795.04
# Minibatch  53000  | loss  0.02 | err rate  0.78%, steps/s 25856.48
# Minibatch  53100  | loss  0.04 | err rate  1.56%, steps/s 26700.73
# ----------------------------------------------------------
# After epoch 68 | valid err rate:  1.08% | doing  79 epochs
# ----------------------------------------------------------
# Minibatch  53200  | loss  0.02 | err rate  0.78%, steps/s 14020.63
# Minibatch  53300  | loss  0.03 | err rate  0.78%, steps/s 25767.91
# Minibatch  53400  | loss  0.04 | err rate  2.34%, steps/s 26459.73
# Minibatch  53500  | loss  0.03 | err rate  1.56%, steps/s 26337.31
# Minibatch  53600  | loss  0.01 | err rate  0.00%, steps/s 26080.60
# Minibatch  53700  | loss  0.09 | err rate  2.34%, steps/s 26304.42
# Minibatch  53800  | loss  0.05 | err rate  1.56%, steps/s 26474.33
# Minibatch  53900  | loss  0.01 | err rate  0.00%, steps/s 25654.45
# ...
# Minibatch  73200  | loss  0.01 | err rate  0.00%, steps/s 34412.78
# Minibatch  73300  | loss  0.02 | err rate  0.00%, steps/s 35105.32
# Minibatch  73400  | loss  0.03 | err rate  0.78%, steps/s 34307.79
# Minibatch  73500  | loss  0.00 | err rate  0.00%, steps/s 36908.15
# ----------------------------------------------------------
# After epoch 94 | valid err rate:  1.06% | doing 116 epochs
# ----------------------------------------------------------
# Minibatch  73600  | loss  0.01 | err rate  0.00%, steps/s 18709.57
# Minibatch  73700  | loss  0.02 | err rate  0.78%, steps/s 36905.67
# Minibatch  73800  | loss  0.03 | err rate  0.78%, steps/s 37796.25
# Minibatch  73900  | loss  0.03 | err rate  0.78%, steps/s 37127.09
# Minibatch  74000  | loss  0.02 | err rate  0.00%, steps/s 36982.23
# Minibatch  74100  | loss  0.03 | err rate  1.56%, steps/s 35495.43
# Minibatch  74200  | loss  0.04 | err rate  3.12%, steps/s 34212.98
# ----------------------------------------------------------
# After epoch 95 | valid err rate:  1.03% | doing 116 epochs
# ----------------------------------------------------------
# Minibatch  74300  | loss  0.01 | err rate  0.00%, steps/s 18432.62
# Minibatch  74400  | loss  0.01 | err rate  0.00%, steps/s 38391.92
# Minibatch  74500  | loss  0.02 | err rate  0.78%, steps/s 37377.36
# Minibatch  74600  | loss  0.03 | err rate  1.56%, steps/s 36184.39
# Minibatch  74700  | loss  0.02 | err rate  0.00%, steps/s 38661.15
# Minibatch  74800  | loss  0.04 | err rate  1.56%, steps/s 37923.96
# Minibatch  74900  | loss  0.02 | err rate  0.78%, steps/s 38285.50
# Minibatch  75000  | loss  0.03 | err rate  0.78%, steps/s 37022.22
# ----------------------------------------------------------
# After epoch 96 | valid err rate:  1.02% | doing 116 epochs
# ----------------------------------------------------------
# Minibatch  75100  | loss  0.01 | err rate  0.00%, steps/s 20326.82
# Minibatch  75200  | loss  0.03 | err rate  0.78%, steps/s 35720.07
# Minibatch  75300  | loss  0.01 | err rate  0.00%, steps/s 36039.22
# Minibatch  75400  | loss  0.01 | err rate  0.78%, steps/s 37374.30
# Minibatch  75500  | loss  0.01 | err rate  0.00%, steps/s 35984.16
# Minibatch  75600  | loss  0.04 | err rate  0.78%, steps/s 35839.27
# Minibatch  75700  | loss  0.01 | err rate  0.78%, steps/s 38100.95
# Minibatch  75800  | loss  0.04 | err rate  0.78%, steps/s 35915.66
# ----------------------------------------------------------
# After epoch 97 | valid err rate:  1.02% | doing 116 epochs
# ----------------------------------------------------------
# Minibatch  75900  | loss  0.01 | err rate  0.00%, steps/s 18859.72
# Minibatch  76000  | loss  0.02 | err rate  0.78%, steps/s 39181.00
# Minibatch  76100  | loss  0.02 | err rate  0.78%, steps/s 39133.20
# Minibatch  76200  | loss  0.01 | err rate  0.00%, steps/s 38191.44
# Minibatch  76300  | loss  0.04 | err rate  1.56%, steps/s 39717.04
# Minibatch  76400  | loss  0.02 | err rate  0.78%, steps/s 39764.68
# Minibatch  76500  | loss  0.04 | err rate  1.56%, steps/s 39660.55
# Minibatch  76600  | loss  0.01 | err rate  0.00%, steps/s 39530.59
# ----------------------------------------------------------
# After epoch 98 | valid err rate:  1.03% | doing 116 epochs
# ----------------------------------------------------------
# Minibatch  76700  | loss  0.03 | err rate  0.78%, steps/s 21391.37
# Minibatch  76800  | loss  0.02 | err rate  0.00%, steps/s 40230.12
# Minibatch  76900  | loss  0.04 | err rate  0.78%, steps/s 37726.01
# Minibatch  77000  | loss  0.02 | err rate  0.78%, steps/s 40710.15
# Minibatch  77100  | loss  0.01 | err rate  0.00%, steps/s 40442.78
# Minibatch  77200  | loss  0.03 | err rate  0.78%, steps/s 38722.92
# Minibatch  77300  | loss  0.05 | err rate  2.34%, steps/s 40031.01
# Minibatch  77400  | loss  0.01 | err rate  0.00%, steps/s 39587.90
# ----------------------------------------------------------
# After epoch 99 | valid err rate:  1.09% | doing 116 epochs
# ----------------------------------------------------------
# Minibatch  77500  | loss  0.02 | err rate  0.78%, steps/s 22114.75
# Minibatch  77600  | loss  0.05 | err rate  2.34%, steps/s 39523.40
# Minibatch  77700  | loss  0.02 | err rate  0.78%, steps/s 40268.53
# Minibatch  77800  | loss  0.02 | err rate  0.78%, steps/s 40084.64
# Minibatch  77900  | loss  0.02 | err rate  0.00%, steps/s 39420.27
# Minibatch  78000  | loss  0.05 | err rate  1.56%, steps/s 39213.21
# Minibatch  78100  | loss  0.02 | err rate  0.78%, steps/s 39555.51
# Minibatch  78200  | loss  0.00 | err rate  0.00%, steps/s 45352.76
# -----------------------------------------------------------
# After epoch 100 | valid err rate:  1.07% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  78300  | loss  0.02 | err rate  0.78%, steps/s 20080.87
# Minibatch  78400  | loss  0.04 | err rate  0.78%, steps/s 38040.53
# Minibatch  78500  | loss  0.00 | err rate  0.00%, steps/s 39540.45
# Minibatch  78600  | loss  0.02 | err rate  0.78%, steps/s 40093.86
# Minibatch  78700  | loss  0.01 | err rate  0.00%, steps/s 39886.23
# Minibatch  78800  | loss  0.05 | err rate  0.78%, steps/s 40496.66
# Minibatch  78900  | loss  0.01 | err rate  0.00%, steps/s 40522.69
# -----------------------------------------------------------
# After epoch 101 | valid err rate:  1.08% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  79000  | loss  0.02 | err rate  0.78%, steps/s 19464.44
# Minibatch  79100  | loss  0.04 | err rate  1.56%, steps/s 40285.16
# Minibatch  79200  | loss  0.01 | err rate  0.00%, steps/s 41194.80
# Minibatch  79300  | loss  0.07 | err rate  2.34%, steps/s 40722.36
# Minibatch  79400  | loss  0.03 | err rate  1.56%, steps/s 41306.11
# Minibatch  79500  | loss  0.05 | err rate  2.34%, steps/s 40907.74
# Minibatch  79600  | loss  0.03 | err rate  0.78%, steps/s 40960.14
# Minibatch  79700  | loss  0.00 | err rate  0.00%, steps/s 40832.08
# -----------------------------------------------------------
# After epoch 102 | valid err rate:  1.04% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  79800  | loss  0.03 | err rate  1.56%, steps/s 22122.82
# Minibatch  79900  | loss  0.03 | err rate  1.56%, steps/s 41857.09
# Minibatch  80000  | loss  0.03 | err rate  2.34%, steps/s 40743.44
# Minibatch  80100  | loss  0.01 | err rate  0.00%, steps/s 41116.99
# Minibatch  80200  | loss  0.01 | err rate  0.00%, steps/s 41650.79
# Minibatch  80300  | loss  0.02 | err rate  0.78%, steps/s 41321.30
# Minibatch  80400  | loss  0.01 | err rate  0.00%, steps/s 41012.70
# Minibatch  80500  | loss  0.01 | err rate  0.00%, steps/s 40739.25
# -----------------------------------------------------------
# After epoch 103 | valid err rate:  1.06% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  80600  | loss  0.01 | err rate  0.00%, steps/s 22649.36
# Minibatch  80700  | loss  0.04 | err rate  2.34%, steps/s 40891.27
# Minibatch  80800  | loss  0.06 | err rate  1.56%, steps/s 42033.02
# Minibatch  80900  | loss  0.01 | err rate  0.00%, steps/s 42119.13
# Minibatch  81000  | loss  0.03 | err rate  0.78%, steps/s 40465.54
# Minibatch  81100  | loss  0.02 | err rate  1.56%, steps/s 42038.69
# Minibatch  81200  | loss  0.01 | err rate  0.00%, steps/s 42134.58
# Minibatch  81300  | loss  0.01 | err rate  0.00%, steps/s 40923.17
# -----------------------------------------------------------
# After epoch 104 | valid err rate:  1.06% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  81400  | loss  0.03 | err rate  0.78%, steps/s 22948.53
# Minibatch  81500  | loss  0.01 | err rate  0.00%, steps/s 43342.28
# Minibatch  81600  | loss  0.02 | err rate  0.00%, steps/s 41025.65
# Minibatch  81700  | loss  0.02 | err rate  0.78%, steps/s 40812.18
# Minibatch  81800  | loss  0.01 | err rate  0.00%, steps/s 42073.92
# Minibatch  81900  | loss  0.02 | err rate  0.00%, steps/s 41182.54
# Minibatch  82000  | loss  0.04 | err rate  1.56%, steps/s 41881.11
# Minibatch  82100  | loss  0.02 | err rate  0.78%, steps/s 44329.05
# -----------------------------------------------------------
# After epoch 105 | valid err rate:  1.06% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  82200  | loss  0.01 | err rate  0.00%, steps/s 22198.81
# Minibatch  82300  | loss  0.02 | err rate  1.56%, steps/s 40675.57
# Minibatch  82400  | loss  0.04 | err rate  2.34%, steps/s 43034.03
# Minibatch  82500  | loss  0.04 | err rate  1.56%, steps/s 41395.34
# Minibatch  82600  | loss  0.02 | err rate  0.78%, steps/s 42092.13
# Minibatch  82700  | loss  0.01 | err rate  0.00%, steps/s 43814.40
# Minibatch  82800  | loss  0.03 | err rate  1.56%, steps/s 42281.71
# -----------------------------------------------------------
# After epoch 106 | valid err rate:  1.08% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  82900  | loss  0.01 | err rate  0.00%, steps/s 22860.97
# Minibatch  83000  | loss  0.04 | err rate  1.56%, steps/s 42801.51
# Minibatch  83100  | loss  0.04 | err rate  1.56%, steps/s 43287.27
# Minibatch  83200  | loss  0.01 | err rate  0.00%, steps/s 42922.73
# Minibatch  83300  | loss  0.01 | err rate  0.00%, steps/s 42797.54
# Minibatch  83400  | loss  0.05 | err rate  0.78%, steps/s 42832.68
# Minibatch  83500  | loss  0.02 | err rate  0.00%, steps/s 42306.69
# Minibatch  83600  | loss  0.01 | err rate  0.00%, steps/s 43941.62
# -----------------------------------------------------------
# After epoch 107 | valid err rate:  1.07% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  83700  | loss  0.02 | err rate  0.78%, steps/s 22960.03
# Minibatch  83800  | loss  0.03 | err rate  0.78%, steps/s 43579.31
# Minibatch  83900  | loss  0.02 | err rate  0.00%, steps/s 42784.74
# Minibatch  84000  | loss  0.04 | err rate  1.56%, steps/s 43998.49
# Minibatch  84100  | loss  0.05 | err rate  0.78%, steps/s 42711.92
# Minibatch  84200  | loss  0.01 | err rate  0.00%, steps/s 44241.89
# Minibatch  84300  | loss  0.03 | err rate  1.56%, steps/s 44432.81
# Minibatch  84400  | loss  0.01 | err rate  0.00%, steps/s 44360.80
# -----------------------------------------------------------
# After epoch 108 | valid err rate:  1.09% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  84500  | loss  0.04 | err rate  0.78%, steps/s 23091.65
# Minibatch  84600  | loss  0.03 | err rate  0.78%, steps/s 43746.63
# Minibatch  84700  | loss  0.02 | err rate  0.00%, steps/s 44346.61
# Minibatch  84800  | loss  0.02 | err rate  0.78%, steps/s 43890.68
# Minibatch  84900  | loss  0.02 | err rate  0.00%, steps/s 44030.40
# Minibatch  85000  | loss  0.03 | err rate  0.78%, steps/s 45270.68
# Minibatch  85100  | loss  0.02 | err rate  0.00%, steps/s 44940.95
# Minibatch  85200  | loss  0.02 | err rate  0.00%, steps/s 43350.13
# -----------------------------------------------------------
# After epoch 109 | valid err rate:  1.10% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  85300  | loss  0.04 | err rate  1.56%, steps/s 24168.29
# Minibatch  85400  | loss  0.06 | err rate  3.12%, steps/s 43894.86
# Minibatch  85500  | loss  0.01 | err rate  0.00%, steps/s 44392.12
# Minibatch  85600  | loss  0.04 | err rate  1.56%, steps/s 43335.41
# Minibatch  85700  | loss  0.01 | err rate  0.00%, steps/s 42959.25
# Minibatch  85800  | loss  0.02 | err rate  0.78%, steps/s 42508.72
# Minibatch  85900  | loss  0.02 | err rate  0.78%, steps/s 42239.04
# Minibatch  86000  | loss  0.03 | err rate  0.00%, steps/s 44186.17
# -----------------------------------------------------------
# After epoch 110 | valid err rate:  1.09% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  86100  | loss  0.01 | err rate  0.00%, steps/s 23979.95
# Minibatch  86200  | loss  0.01 | err rate  0.00%, steps/s 44116.80
# Minibatch  86300  | loss  0.01 | err rate  0.00%, steps/s 43064.22
# Minibatch  86400  | loss  0.01 | err rate  0.00%, steps/s 44463.28
# Minibatch  86500  | loss  0.01 | err rate  0.78%, steps/s 43907.80
# Minibatch  86600  | loss  0.01 | err rate  0.00%, steps/s 44341.12
# Minibatch  86700  | loss  0.02 | err rate  0.78%, steps/s 44162.96
# Minibatch  86800  | loss  0.02 | err rate  0.78%, steps/s 49485.03
# -----------------------------------------------------------
# After epoch 111 | valid err rate:  1.06% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  86900  | loss  0.02 | err rate  0.78%, steps/s 22869.03
# Minibatch  87000  | loss  0.07 | err rate  1.56%, steps/s 43420.28
# Minibatch  87100  | loss  0.02 | err rate  0.78%, steps/s 44215.86
# Minibatch  87200  | loss  0.05 | err rate  0.78%, steps/s 43781.72
# Minibatch  87300  | loss  0.02 | err rate  0.00%, steps/s 43942.30
# Minibatch  87400  | loss  0.01 | err rate  0.00%, steps/s 44565.13
# Minibatch  87500  | loss  0.02 | err rate  0.00%, steps/s 44317.32
# -----------------------------------------------------------
# After epoch 112 | valid err rate:  1.06% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  87600  | loss  0.02 | err rate  0.78%, steps/s 23755.51
# Minibatch  87700  | loss  0.01 | err rate  0.00%, steps/s 44148.31
# Minibatch  87800  | loss  0.04 | err rate  1.56%, steps/s 44425.86
# Minibatch  87900  | loss  0.01 | err rate  0.00%, steps/s 43420.85
# Minibatch  88000  | loss  0.01 | err rate  0.00%, steps/s 43582.74
# Minibatch  88100  | loss  0.03 | err rate  1.56%, steps/s 43583.53
# Minibatch  88200  | loss  0.02 | err rate  0.78%, steps/s 44110.71
# Minibatch  88300  | loss  0.05 | err rate  0.78%, steps/s 44084.26
# -----------------------------------------------------------
# After epoch 113 | valid err rate:  1.10% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  88400  | loss  0.03 | err rate  1.56%, steps/s 23675.87
# Minibatch  88500  | loss  0.04 | err rate  1.56%, steps/s 44312.65
# Minibatch  88600  | loss  0.02 | err rate  0.00%, steps/s 46043.43
# Minibatch  88700  | loss  0.06 | err rate  1.56%, steps/s 45221.40
# Minibatch  88800  | loss  0.04 | err rate  1.56%, steps/s 43636.30
# Minibatch  88900  | loss  0.03 | err rate  0.00%, steps/s 43813.45
# Minibatch  89000  | loss  0.01 | err rate  0.00%, steps/s 44903.67
# Minibatch  89100  | loss  0.05 | err rate  0.78%, steps/s 45283.18
# -----------------------------------------------------------
# After epoch 114 | valid err rate:  1.09% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  89200  | loss  0.02 | err rate  0.78%, steps/s 24124.77
# Minibatch  89300  | loss  0.01 | err rate  0.00%, steps/s 44574.83
# Minibatch  89400  | loss  0.01 | err rate  0.00%, steps/s 44755.57
# Minibatch  89500  | loss  0.03 | err rate  0.78%, steps/s 43715.86
# Minibatch  89600  | loss  0.04 | err rate  2.34%, steps/s 46910.61
# Minibatch  89700  | loss  0.02 | err rate  0.00%, steps/s 43507.82
# Minibatch  89800  | loss  0.02 | err rate  0.78%, steps/s 46451.25
# Minibatch  89900  | loss  0.01 | err rate  0.00%, steps/s 46286.33
# -----------------------------------------------------------
# After epoch 115 | valid err rate:  1.08% | doing 116 epochs
# -----------------------------------------------------------
# Minibatch  90000  | loss  0.05 | err rate  0.78%, steps/s 24521.98
# Minibatch  90100  | loss  0.02 | err rate  0.00%, steps/s 45544.91
# Minibatch  90200  | loss  0.02 | err rate  0.78%, steps/s 45097.89
# Minibatch  90300  | loss  0.02 | err rate  0.78%, steps/s 46241.81
# Minibatch  90400  | loss  0.01 | err rate  0.78%, steps/s 44978.75
# Minibatch  90500  | loss  0.02 | err rate  0.00%, steps/s 45920.95
# Minibatch  90600  | loss  0.02 | err rate  0.00%, steps/s 45770.91
# Minibatch  90700  | loss  0.01 | err rate  0.00%, steps/s 45770.93
# -----------------------------------------------------------
# After epoch 116 | valid err rate:  1.07% | doing 116 epochs
# -----------------------------------------------------------
#
# Loading best params on validation set (epoch 77)
#
# Test error rate: 1.16%

# %% [markdown]
# # Problem 5: Batch Normalization [1p]
#
# *Covariate shift* is a phenomenon associated with training deep models. Simply put, weight changes in early layers cause major changes in distribution of inputs to later layers, making it difficult to train later layers.
#
# [Batch Normalization](https://arxiv.org/abs/1502.03167) addresses this problem by normalizing distributions of inputs to layers within mini-batches. It typically allows to train networks faster and/or with higher learning rates, lessens the importance
# of initialization and might eliminate the need for Dropout.
#
# Implement Batch Normalization and compare with regular training of MNIST models.
#
# Remember to use the batch statistics during model training and to use an average of training batch statistics during model evaluation. For details please consult the paper.

# %% [markdown]
# # Problem 6: Norm Constraints [1p bonus]
#
# Implement norm constraints, i.e. instead of weight decay, that tries to set
# all weights to small values, apply a limit on the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").
#
# Please consult the Dropout paper (http://arxiv.org/pdf/1207.0580.pdf) for details.

# %% [markdown]
# # Problem 6: Polyak Averaging [1p bonus]
#
# Implement Polyak averaging. For each parameter $\theta$
# keep a separate, exponentially decayed average of the past values
# $$
# \bar{\theta}_n = \alpha_p\bar{\theta}_{n-1} + (1-\alpha_p)\theta_n.
# $$
# Use that average when evaluating the model on the test set.
# Validate the approach by training a model on the MNIST dataset.

# %% [markdown]
# # Problem 7: Convolutional Network [2p bonus]
#
# Use convolutional and max-pooling layers (`torch.nn.functional.conv2d`, `torch.nn.functional.max_pool2d`) and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 8: Hyperparameter tuner [1p bonus]
#
# Implement a hyper-parameter tuner able to optimize the learing rate schedule, number of neurons and similar hyperparameters. For start, use random search (please see http://jmlr.csail.mit.edu/papers/volume13/bergstra12a/bergstra12a.pdf and especially Fig 1. for intuitions on why random search is better than grid search). It may be a good idea to use a fixed maximum number of epochs (or training time) for each optimization trial to prevent selecting hyperparameters that yield slowly converging solutions. A good result will be a set of hyperparameters that reach on MNIST solutions with test errors less than $1.3\%$ in no more than 50 epochs.
